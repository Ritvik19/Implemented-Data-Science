# %% [markdown]
# # Tabular ResNet
# Introduced in the paper [Revisiting Deep Learning Models for Tabular Data (2021, June)](https://arxiv.org/abs/2106.11959) Tabular Resnet is a ResNet like architecture containing skip connection but instead of Convolutional Layers, it consists of Linear Layers

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers as L
from tensorflow_addons.activations import sparsemax

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
import joblib

pd.options.display.max_columns = 300

# %% [markdown]
# # Data

# %%
data = pd.read_csv('../input/tabular-playground-series-feb-2022/train.csv')
data = data.drop_duplicates(subset=data.columns[1:]).reset_index(drop=True)
print(data.shape)
data.head()
# Out:
# (123993, 288)
#    row_id     A0T0G0C10  A0T0G1C9  A0T0G2C8  A0T0G3C7  A0T0G4C6  A0T0G5C5  \
# 0       0 -9.536743e-07 -0.000010 -0.000043 -0.000114 -0.000200 -0.000240
# 1       1 -9.536743e-07 -0.000010 -0.000043  0.000886 -0.000200  0.000760
# 2       2 -9.536743e-07 -0.000002  0.000007  0.000129  0.000268  0.000270
# 3       3  4.632568e-08 -0.000006  0.000012  0.000245  0.000492  0.000522
# 4       4 -9.536743e-07 -0.000010 -0.000043 -0.000114 -0.000200 -0.000240
#
#    A0T0G6C4  A0T0G7C3  A0T0G8C2  A0T0G9C1     A0T0G10C0  A0T1G0C9  \
# 0 -0.000200 -0.000114 -0.000043 -0.000010 -9.536743e-07 -0.000010
# 1 -0.000200 -0.000114 -0.000043 -0.000010 -9.536743e-07 -0.000010
# 2  0.000243  0.000125  0.000001 -0.000007  4.632568e-08 -0.000004
# 3  0.000396  0.000197 -0.000003 -0.000007 -9.536743e-07 -0.000010
# 4 -0.000200 -0.000114 -0.000043 -0.000010 -9.536743e-07 -0.000010
#
#        A0T1G1C8  A0T1G2C7  A0T1G3C6  A0T1G4C5  A0T1G5C4  A0T1G6C3  A0T1G7C2  \
# 0 -8.583069e-05 -0.000343 -0.000801 -0.001202 -0.001202 -0.000801 -0.000343
# 1 -8.583069e-05 -0.000343  0.000199 -0.000202  0.001798 -0.000801 -0.000343
# 2  1.693115e-07  0.000008  0.000366  0.000766  0.000937  0.000632  0.000101
# 3 -1.783069e-05  0.000068  0.000722  0.001594  0.001913  0.001111  0.000247
# 4 -8.583069e-05 -0.000343 -0.000801 -0.001202 -0.001202 -0.000801 -0.000343
#
#    A0T1G8C1  A0T1G9C0      A0T2G0C8  A0T2G1C7  A0T2G2C6  A0T2G3C5  A0T2G4C4  \
# 0 -0.000086 -0.000010 -4.291534e-05 -0.000343 -0.001202 -0.002403 -0.003004
# 1 -0.000086 -0.000010 -4.291534e-05 -0.000343  0.001798 -0.000403  0.001996
# 2 -0.000021 -0.000008  8.465576e-08 -0.000080  0.000114  0.000710  0.001307
# 3 -0.000047 -0.000010 -1.891534e-05 -0.000138  0.000161  0.001345  0.002526
# 4 -0.000086 -0.000010 -4.291534e-05 -0.000343 -0.001202 -0.002403 -0.003004
#
#    A0T2G5C3  A0T2G6C2  A0T2G7C1  A0T2G8C0  A0T3G0C7  A0T3G1C6  A0T3G2C5  \
# 0 -0.002403 -0.001202 -0.000343 -0.000043 -0.000114 -0.000801 -0.002403
# 1  0.003597 -0.001202 -0.000343 -0.000043 -0.000114 -0.000801 -0.000403
# 2  0.001065  0.000375 -0.000017 -0.000017 -0.000014 -0.000094  0.000183
# 3  0.002155  0.000754 -0.000029 -0.000025 -0.000034 -0.000179  0.000345
# 4 -0.002403 -0.001202 -0.000343 -0.000043 -0.000114 -0.000801 -0.002403
#
#    A0T3G3C4  A0T3G4C3  A0T3G5C2  A0T3G6C1  A0T3G7C0  A0T4G0C6  A0T4G1C5  \
# 4 -0.004807 -0.001202  0.009199  0.007597 -0.002403 -0.000801 -0.000343
#
#    A1T7G1C1  A1T7G2C0  A1T8G0C1  A1T8G1C0  A1T9G0C0  A2T0G0C8  A2T0G1C7  \
# 0 -0.000687 -0.000343 -0.000086 -0.000086 -0.000010 -0.000043 -0.000343
# 1  0.001313  0.000657 -0.000086 -0.000086 -0.000010 -0.000043  0.000657
# 2  0.000297  0.000084  0.000123  0.000090  0.000021 -0.000010 -0.000025
# 3  0.000582  0.000212  0.000244  0.000172  0.000042 -0.000020 -0.000004
# 4 -0.000687 -0.000343 -0.000086 -0.000086 -0.000010 -0.000043 -0.000343
#
#    A2T0G2C6  A2T0G3C5  A2T0G4C4  A2T0G5C3  A2T0G6C2  A2T0G7C1  A2T0G8C0  \
# 0 -0.001202 -0.002403 -0.003004 -0.002403 -0.001202 -0.000343 -0.000043
# 1 -0.001202  0.001597 -0.002004 -0.000403  0.001798 -0.000343 -0.000043
# 2  0.000365  0.001105  0.001269  0.000726  0.000031 -0.000063 -0.000007
# 3  0.000738  0.002100  0.002546  0.001449  0.000121 -0.000089 -0.000020
# 4 -0.001202 -0.002403 -0.003004 -0.002403 -0.001202 -0.000343 -0.000043
#
#    A2T1G0C7  A2T1G1C6  A2T1G2C5  A2T1G3C4  A2T1G4C3  A2T1G5C2  A2T1G6C1  \
# 0 -0.000343 -0.002403 -0.007210 -0.012016 -0.002016 -0.007210 -0.002403
# 1 -0.000343  0.000597 -0.000210 -0.002016 -0.000016 -0.001210 -0.000403
# 2 -0.000088 -0.000165  0.000774  0.002056  0.001407  0.000417 -0.000313
# 3 -0.000188 -0.000388  0.001525  0.003620  0.003440  0.000862 -0.000598
# 4 -0.000343 -0.002403 -0.007210 -0.012016 -0.012016 -0.007210 -0.002403
#
#    A2T1G7C0  A2T2G0C6  A2T2G1C5  A2T2G2C4  A2T2G3C3  A2T2G4C2  A2T2G5C1  \
# 0 -0.000343  0.008798 -0.007210  0.011976 -0.014033  0.021976  0.012790
# 1 -0.000343  0.000798 -0.001210  0.007976 -0.001033  0.001976 -0.002210
# 2 -0.000084 -0.000273 -0.000725 -0.000100  0.000122 -0.000102 -0.000707
# 3 -0.000160 -0.000516 -0.001558 -0.000150  0.000439 -0.000553 -0.001339
# 4 -0.000343 -0.001202 -0.007210 -0.018024 -0.024033 -0.018024  0.002790
#
#    A2T2G6C0  A2T3G0C5  A2T3G1C4  A2T3G2C3  A2T3G3C2  A2T3G4C1  A2T3G5C0  \
# 0 -0.001202 -0.002403 -0.012016 -0.014033 -0.004033 -0.002016 -0.002403
# 1 -0.001202  0.000597 -0.005016 -0.001033 -0.002033 -0.001016 -0.002403
# 2 -0.000276 -0.000544 -0.001238 -0.001388 -0.001945 -0.001202 -0.000434
# 3 -0.000573 -0.000909 -0.002356 -0.003248 -0.003088 -0.002446 -0.000983
# 4 -0.001202 -0.002403 -0.012016 -0.004033 -0.024033 -0.002016 -0.002403
#
#    A2T4G0C4  A2T4G1C3  A2T4G2C2  A2T4G3C1  A2T4G4C0  A2T5G0C3  A2T5G1C2  \
-0.000801 -0.000200 -0.000114 -0.000343 -0.000343 -0.000114
# 1  0.001199  0.001199  0.000800 -0.000114 -0.000343 -0.000343 -0.000114
# 2  0.000203  0.000238  0.000120  0.000027  0.000097  0.000159  0.000070
# 3  0.000401  0.000412  0.000246  0.000047  0.000160  0.000309  0.000129
# 4 -0.000801 -0.000801 -0.000200 -0.000114 -0.000343 -0.000343 -0.000114
#
#    A7T1G0C2  A7T1G1C1  A7T1G2C0  A7T2G0C1  A7T2G1C0  A7T3G0C0  A8T0G0C2  \
# 0 -0.000343 -0.000687 -0.000343 -0.000343 -0.000343 -0.000114 -0.000043
# 1 -0.000343  0.001313  0.000657  0.001657  0.001657  0.000886 -0.000043
# 2  0.000138  0.000315  0.000214  0.000178  0.000296  0.000118  0.000042
# 3  0.000243  0.000597  0.000428  0.000363  0.000472  0.000197  0.000068
# 4 -0.000343  0.009313 -0.000343 -0.000343  0.009657 -0.000114 -0.000043
#
#    A8T0G1C1  A8T0G2C0  A8T1G0C1  A8T1G1C0  A8T2G0C0  A9T0G0C1  A9T0G1C0  \
# 0 -0.000086 -0.000043 -0.000086 -0.000086 -0.000043 -0.000010 -0.000010
# 1 -0.000086 -0.000043  0.000914  0.000914 -0.000043 -0.000010 -0.000010
# 2  0.000084  0.000048  0.000081  0.000106  0.000072  0.000010  0.000008
# 3  0.000151  0.000100  0.000180  0.000202  0.000153  0.000021  0.000015
# 4 -0.000086 -0.000043 -0.000086 -0.000086 -0.000043 -0.000010 -0.000010
#
#    A9T1G0C0     A10T0G0C0                  target
# 0 -0.000010 -9.536743e-07  Streptococcus_pyogenes
# 1 -0.000010 -9.536743e-07     Salmonella_enterica
# 2  0.000019  1.046326e-06     Salmonella_enterica
# 3  0.000046 -9.536743e-07     Salmonella_enterica
# 4 -0.000010 -9.536743e-07      Enterococcus_hirae

# %%
test = pd.read_csv('../input/tabular-playground-series-feb-2022/test.csv')
print(test.shape)
X_test = test.drop(['row_id'], axis=1)
# Out:
# (100000, 287)

# %%
X = data.drop(['row_id', 'target'], axis=1)
y = pd.get_dummies(data['target'])

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# # Model

# %%
class DataConfig:
    def __init__(self, numeric_feature_names, categorical_features_with_vocabulary):
        self.NUMERIC_FEATURE_NAMES = numeric_feature_names
        self.CATEGORICAL_FEATURES_WITH_VOCABULARY = categorical_features_with_vocabulary
        self.CATEGORICAL_FEATURE_NAMES = list(self.CATEGORICAL_FEATURES_WITH_VOCABULARY.keys())
        self.FEATURE_NAMES = self.NUMERIC_FEATURE_NAMES + self.CATEGORICAL_FEATURE_NAMES
        
from tensorflow.data import Dataset


class DataLoader:
    @classmethod
    def from_df(cls, X, y=None, batch_size=1024):
        return (
            Dataset.from_tensor_slices(({col: X[col].values.tolist() for col in X.columns}, y.values.tolist())).batch(
                batch_size
            )
            if y is not None
            else Dataset.from_tensor_slices({col: X[col].values.tolist() for col in X.columns}).batch(batch_size)
        )

# %%
def get_inputs(config):
    return {
        feature_name: L.Input(
            name=feature_name,
            shape=(),
            dtype=(tf.float32 if feature_name in config.NUMERIC_FEATURE_NAMES else tf.string),
        )
        for feature_name in config.FEATURE_NAMES
    }

def encode_inputs(inputs, config, use_embeddings=False, embedding_dim=32, prefix="", concat_features=False):
    cat_features = []
    num_features = []
    for feature_name in inputs:
        if feature_name in config.CATEGORICAL_FEATURE_NAMES:
            vocabulary = config.CATEGORICAL_FEATURES_WITH_VOCABULARY[feature_name]
            lookup = L.StringLookup(
                vocabulary=vocabulary,
                mask_token=None,
                num_oov_indices=0,
                output_mode="int" if use_embeddings else "binary",
                name=f"{prefix}{feature_name}_lookup",
            )
            if use_embeddings:
                encoded_feature = lookup(inputs[feature_name])
                embedding = L.Embedding(
                    input_dim=len(vocabulary),
                    output_dim=embedding_dim,
                    name=f"{prefix}{feature_name}_embeddings",
                )
                encoded_feature = embedding(encoded_feature)
            else:
                encoded_feature = lookup(
                    L.Reshape((1,), name=f"{prefix}{feature_name}_reshape")(inputs[feature_name])
                )
            cat_features.append(encoded_feature)
        else:
            encoded_feature = L.Reshape((1,), name=f"{prefix}{feature_name}_reshape")(inputs[feature_name])
            num_features.append(encoded_feature)

    features = (
        L.Concatenate(name=f"{prefix}inputs_concatenate")(cat_features + num_features)
        if concat_features
        else (cat_features, num_features)
    )

    return features

# %%
class TabularResNetConfig:
    def __init__(
        self, num_outputs, out_activation, hidden_units, dropout_rate=0.3, use_embeddings=True, embedding_dim=32
    ):
        self.NUM_OUT = num_outputs
        self.OUT_ACTIVATION = out_activation
        self.HIDDEN_UNITS = hidden_units
        self.DROPOUT_RATE = dropout_rate
        self.USE_EMBEDDINGS = use_embeddings
        self.EMBEDDING_DIM = embedding_dim

# %%
def skip_connection(inputs, units, i, dropout_rate):
    inputs = L.Dense(units, name=f"block_{i+1}_1_dense")(inputs)
    inputs = L.BatchNormalization(name=f"block_{i+1}_1_b_norm")(inputs)
    inputs = L.ReLU(name=f"block_{i+1}_1_relu")(inputs)
    inputs = L.Dropout(dropout_rate, name=f"block_{i+1}_1_dropout")(inputs)
    x = L.Dense(units, name=f"block_{i+1}_2_dense")(inputs)
    x = L.BatchNormalization(name=f"block_{i+1}_2_b_norm")(x)
    x = L.ReLU(name=f"block_{i+1}_2_relu")(x)
    x = L.Dropout(dropout_rate, name=f"block_{i+1}_2_dropout")(x)
    return L.Add(name=f"skip_{i+1}")([inputs, x])

class TabularResNet:
    @classmethod
    def from_config(cls, data_config, model_config, name):
        inputs = get_inputs(data_config)
        features = encode_inputs(
            inputs,
            data_config,
            use_embeddings=True,
            embedding_dim=model_config.EMBEDDING_DIM,
            prefix="",
            concat_features=True,
        )
        for i, units in enumerate(model_config.HIDDEN_UNITS):
            features = skip_connection(features, units, i, model_config.DROPOUT_RATE)
        outputs = L.Dense(
            units=model_config.NUM_OUT,
            activation=model_config.OUT_ACTIVATION,
            name="outputs",
        )(features)
        model = keras.Model(inputs=inputs, outputs=outputs, name=name)
        return model

# %%
data_config = DataConfig(
    numeric_feature_names=X.columns.tolist(), categorical_features_with_vocabulary={}
)
model_config = TabularResNetConfig(num_outputs=len(y.columns), out_activation='softmax', hidden_units=[128, 64, 32])

# %%
blank_model = TabularResNet.from_config(data_config, model_config, name='tab_resnet')
blank_model.summary()
# Out:
# 2022-02-19 16:02:01.179233: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "tab_resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# A0T0G0C10 (InputLayer)          [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G1C9 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G2C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G3C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G4C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G5C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G6C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G7C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G8C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G9C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G10C0 (InputLayer)          [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G0C9 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G1C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G2C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G3C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G4C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G5C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G6C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G7C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G8C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G9C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G0C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G1C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G2C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G3C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G4C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G5C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G6C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G7C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G8C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G0C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G1C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G2C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G3C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G4C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G5C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G6C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G7C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G0C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G1C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G2C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G3C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G4C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G5C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G6C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T6G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T6G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T6G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T6G3C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T6G4C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T7G0C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T7G1C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T7G2C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T7G3C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T8G0C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T8G1C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T8G2C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T9G0C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T9G1C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T10G0C0 (InputLayer)          [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G0C9 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G1C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G2C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G3C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G4C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G5C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G6C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G7C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G8C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G9C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G0C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G1C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G2C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G3C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G4C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G5C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G6C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G7C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G8C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G0C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G1C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G2C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G3C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G4C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G5C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G6C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G7C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G0C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G1C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G2C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G3C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G4C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G5C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G6C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T5G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T5G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T5G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T5G3C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T5G4C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T6G0C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T6G1C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T6G2C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T6G3C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T7G0C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T7G1C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T7G2C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T8G0C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T8G1C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T9G0C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G0C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G1C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G2C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G3C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G4C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G5C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G6C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G7C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G8C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G0C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G1C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G2C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G3C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G4C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G5C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G6C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G7C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G0C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G1C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G2C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G3C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G4C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G5C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G6C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T4G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T4G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T4G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T4G3C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T4G4C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T5G0C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T5G1C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T5G2C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T5G3C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T6G0C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T6G1C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T6G2C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T7G0C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T7G1C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T8G0C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G0C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G1C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G2C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G3C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G4C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G5C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G6C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G7C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G0C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G1C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G2C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G3C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G4C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G5C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G6C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T3G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T3G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T3G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T3G3C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T3G4C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T4G0C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T4G1C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T4G2C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T4G3C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T5G0C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T5G1C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T5G2C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T6G0C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T6G1C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T7G0C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G0C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G1C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G2C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G3C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G4C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G5C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G6C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T2G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T2G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T2G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T2G3C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T2G4C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T3G0C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T3G1C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T3G2C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T3G3C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T4G0C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T4G1C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T4G2C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T5G0C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T5G1C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T6G0C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A5T0G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A5T0G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A5T0G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A5T0G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A5T0G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A5T0G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A5T1G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A5T1G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A5T1G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A5T1G3C1 (InputLayer)           [(None,)]            0
# ...
#                                                                  A3T3G0C4_reshape[0][0]
#                                                                  A3T3G1C3_reshape[0][0]
#                                                                  A3T3G2C2_reshape[0][0]
#                                                                  A3T3G3C1_reshape[0][0]
#                                                                  A3T3G4C0_reshape[0][0]
#                                                                  A3T4G0C3_reshape[0][0]
#                                                                  A3T4G1C2_reshape[0][0]
#                                                                  A3T4G2C1_reshape[0][0]
#                                                                  A3T4G3C0_reshape[0][0]
#                                                                  A3T5G0C2_reshape[0][0]
#                                                                  A3T5G1C1_reshape[0][0]
#                                                                  A3T5G2C0_reshape[0][0]
#                                                                  A3T6G0C1_reshape[0][0]
#                                                                  A3T6G1C0_reshape[0][0]
#                                                                  A3T7G0C0_reshape[0][0]
#                                                                  A4T0G0C6_reshape[0][0]
#                                                                  A4T0G1C5_reshape[0][0]
#                                                                  A4T0G2C4_reshape[0][0]
#                                                                  A4T0G3C3_reshape[0][0]
#                                                                  A4T0G4C2_reshape[0][0]
#                                                                  A4T0G5C1_reshape[0][0]
#                                                                  A4T0G6C0_reshape[0][0]
#                                                                  A4T1G0C5_reshape[0][0]
#                                                                  A4T1G1C4_reshape[0][0]
#                                                                  A4T1G2C3_reshape[0][0]
#                                                                  A4T1G3C2_reshape[0][0]
#                                                                  A4T1G4C1_reshape[0][0]
#                                                                  A4T1G5C0_reshape[0][0]
#                                                                  A4T2G0C4_reshape[0][0]
#                                                                  A4T2G1C3_reshape[0][0]
#                                                                  A4T2G2C2_reshape[0][0]
#                                                                  A4T2G3C1_reshape[0][0]
#                                                                  A4T2G4C0_reshape[0][0]
#                                                                  A4T3G0C3_reshape[0][0]
#                                                                  A4T3G1C2_reshape[0][0]
#                                                                  A4T3G2C1_reshape[0][0]
#                                                                  A4T3G3C0_reshape[0][0]
#                                                                  A4T4G0C2_reshape[0][0]
#                                                                  A4T4G1C1_reshape[0][0]
#                                                                  A4T4G2C0_reshape[0][0]
#                                                                  A4T5G0C1_reshape[0][0]
#                                                                  A4T5G1C0_reshape[0][0]
#                                                                  A4T6G0C0_reshape[0][0]
#                                                                  A5T0G0C5_reshape[0][0]
#                                                                  A5T0G1C4_reshape[0][0]
#                                                                  A5T0G2C3_reshape[0][0]
#                                                                  A5T0G3C2_reshape[0][0]
#                                                                  A5T0G4C1_reshape[0][0]
#                                                                  A5T0G5C0_reshape[0][0]
#                                                                  A5T1G0C4_reshape[0][0]
#                                                                  A5T1G1C3_reshape[0][0]
#                                                                  A5T1G2C2_reshape[0][0]
#                                                                  A5T1G3C1_reshape[0][0]
#                                                                  A5T1G4C0_reshape[0][0]
#                                                                  A5T2G0C3_reshape[0][0]
#                                                                  A5T2G1C2_reshape[0][0]
#                                                                  A5T2G2C1_reshape[0][0]
#                                                                  A5T2G3C0_reshape[0][0]
#                                                                  A5T3G0C2_reshape[0][0]
#                                                                  A5T3G1C1_reshape[0][0]
#                                                                  A5T3G2C0_reshape[0][0]
#                                                                  A5T4G0C1_reshape[0][0]
#                                                                  A5T4G1C0_reshape[0][0]
#                                                                  A5T5G0C0_reshape[0][0]
#                                                                  A6T0G0C4_reshape[0][0]
#                                                                  A6T0G1C3_reshape[0][0]
#                                                                  A6T0G2C2_reshape[0][0]
#                                                                  A6T0G3C1_reshape[0][0]
#                                                                  A6T0G4C0_reshape[0][0]
#                                                                  A6T1G0C3_reshape[0][0]
#                                                                  A6T1G1C2_reshape[0][0]
#                                                                  A6T1G2C1_reshape[0][0]
#                                                                  A6T1G3C0_reshape[0][0]
#                                                                  A6T2G0C2_reshape[0][0]
#                                                                  A6T2G1C1_reshape[0][0]
#                                                                  A6T2G2C0_reshape[0][0]
#                                                                  A6T3G0C1_reshape[0][0]
#                                                                  A6T3G1C0_reshape[0][0]
#                                                                  A6T4G0C0_reshape[0][0]
#                                                                  A7T0G0C3_reshape[0][0]
#                                                                  A7T0G1C2_reshape[0][0]
#                                                                  A7T0G2C1_reshape[0][0]
#                                                                  A7T0G3C0_reshape[0][0]
#                                                                  A7T1G0C2_reshape[0][0]
#                                                                  A7T1G1C1_reshape[0][0]
#                                                                  A7T1G2C0_reshape[0][0]
#                                                                  A7T2G0C1_reshape[0][0]
#                                                                  A7T2G1C0_reshape[0][0]
#                                                                  A7T3G0C0_reshape[0][0]
#                                                                  A8T0G0C2_reshape[0][0]
#                                                                  A8T0G1C1_reshape[0][0]
#                                                                  A8T0G2C0_reshape[0][0]
#                                                                  A8T1G0C1_reshape[0][0]
#                                                                  A8T1G1C0_reshape[0][0]
#                                                                  A8T2G0C0_reshape[0][0]
#                                                                  A9T0G0C1_reshape[0][0]
#                                                                  A9T0G1C0_reshape[0][0]
#                                                                  A9T1G0C0_reshape[0][0]
#                                                                  A10T0G0C0_reshape[0][0]
# __________________________________________________________________________________________________
# block_1_1_dense (Dense)         (None, 128)          36736       inputs_concatenate[0][0]
# __________________________________________________________________________________________________
# block_1_1_b_norm (BatchNormaliz (None, 128)          512         block_1_1_dense[0][0]
# __________________________________________________________________________________________________
# block_1_1_relu (ReLU)           (None, 128)          0           block_1_1_b_norm[0][0]
# __________________________________________________________________________________________________
# block_1_1_dropout (Dropout)     (None, 128)          0           block_1_1_relu[0][0]
# __________________________________________________________________________________________________
# block_1_2_dense (Dense)         (None, 128)          16512       block_1_1_dropout[0][0]
# __________________________________________________________________________________________________
# block_1_2_b_norm (BatchNormaliz (None, 128)          512         block_1_2_dense[0][0]
# __________________________________________________________________________________________________
# block_1_2_relu (ReLU)           (None, 128)          0           block_1_2_b_norm[0][0]
# __________________________________________________________________________________________________
# block_1_2_dropout (Dropout)     (None, 128)          0           block_1_2_relu[0][0]
# __________________________________________________________________________________________________
# skip_1 (Add)                    (None, 128)          0           block_1_1_dropout[0][0]
#                                                                  block_1_2_dropout[0][0]
# __________________________________________________________________________________________________
# block_2_1_dense (Dense)         (None, 64)           8256        skip_1[0][0]
# __________________________________________________________________________________________________
# block_2_1_b_norm (BatchNormaliz (None, 64)           256         block_2_1_dense[0][0]
# __________________________________________________________________________________________________
# block_2_1_relu (ReLU)           (None, 64)           0           block_2_1_b_norm[0][0]
# __________________________________________________________________________________________________
# block_2_1_dropout (Dropout)     (None, 64)           0           block_2_1_relu[0][0]
# __________________________________________________________________________________________________
# block_2_2_dense (Dense)         (None, 64)           4160        block_2_1_dropout[0][0]
# __________________________________________________________________________________________________
# block_2_2_b_norm (BatchNormaliz (None, 64)           256         block_2_2_dense[0][0]
# __________________________________________________________________________________________________
# block_2_2_relu (ReLU)           (None, 64)           0           block_2_2_b_norm[0][0]
# __________________________________________________________________________________________________
# block_2_2_dropout (Dropout)     (None, 64)           0           block_2_2_relu[0][0]
# __________________________________________________________________________________________________
# skip_2 (Add)                    (None, 64)           0           block_2_1_dropout[0][0]
#                                                                  block_2_2_dropout[0][0]
# __________________________________________________________________________________________________
# block_3_1_dense (Dense)         (None, 32)           2080        skip_2[0][0]
# __________________________________________________________________________________________________
# block_3_1_b_norm (BatchNormaliz (None, 32)           128         block_3_1_dense[0][0]
# __________________________________________________________________________________________________
# block_3_1_relu (ReLU)           (None, 32)           0           block_3_1_b_norm[0][0]
# __________________________________________________________________________________________________
# block_3_1_dropout (Dropout)     (None, 32)           0           block_3_1_relu[0][0]
# __________________________________________________________________________________________________
# block_3_2_dense (Dense)         (None, 32)           1056        block_3_1_dropout[0][0]
# __________________________________________________________________________________________________
# block_3_2_b_norm (BatchNormaliz (None, 32)           128         block_3_2_dense[0][0]
# __________________________________________________________________________________________________
# block_3_2_relu (ReLU)           (None, 32)           0           block_3_2_b_norm[0][0]
# __________________________________________________________________________________________________
# block_3_2_dropout (Dropout)     (None, 32)           0           block_3_2_relu[0][0]
# __________________________________________________________________________________________________
# skip_3 (Add)                    (None, 32)           0           block_3_1_dropout[0][0]
#                                                                  block_3_2_dropout[0][0]
# __________________________________________________________________________________________________
# outputs (Dense)                 (None, 10)           330         skip_3[0][0]
# ==================================================================================================
# Total params: 70,922
# Trainable params: 70,026
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
MAX_EPOCHS  = 50

get_callbacks = lambda : [
    keras.callbacks.EarlyStopping(min_delta=1e-4, patience=3, verbose=1, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(patience=2, verbose=1)
]

# %% [markdown]
# # Training Loop

# %%
preds = []

for fold, (train_index, valid_index) in enumerate(skf.split(X, data['target'])):
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
    
    scaler = StandardScaler().fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
    X_valid = pd.DataFrame(scaler.transform(X_valid), columns=X.columns)
    x_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)
    
    data_train = DataLoader.from_df(X_train, y_train, batch_size=512)
    data_valid = DataLoader.from_df(X_valid, y_valid, batch_size=512)
    data_test = DataLoader.from_df(x_test, batch_size=512)
    
    model = TabularResNet.from_config(data_config, model_config, name=f'tab_resnet_fold_{fold}')
    model.compile(
        loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy']
    )
    model.fit(
        data_train, validation_data=data_valid, callbacks=get_callbacks(), 
        epochs=MAX_EPOCHS
    )  
    preds.append(model.predict(data_test))
# Out:
# Epoch 1/50
# 2022-02-19 16:06:41.315640: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 194/194 [==============================] - 49s 202ms/step - loss: 1.5849 - accuracy: 0.4399 - val_loss: 0.6693 - val_accuracy: 0.7536
# Epoch 2/50
# 194/194 [==============================] - 34s 176ms/step - loss: 0.7629 - accuracy: 0.7200 - val_loss: 0.3759 - val_accuracy: 0.8994
# Epoch 3/50
# 194/194 [==============================] - 34s 176ms/step - loss: 0.5865 - accuracy: 0.7915 - val_loss: 0.2927 - val_accuracy: 0.9064
# Epoch 4/50
# 194/194 [==============================] - 34s 175ms/step - loss: 0.4981 - accuracy: 0.8261 - val_loss: 0.2492 - val_accuracy: 0.9147
# Epoch 5/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.4450 - accuracy: 0.8437 - val_loss: 0.2225 - val_accuracy: 0.9141
# Epoch 6/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.4006 - accuracy: 0.8593 - val_loss: 0.2095 - val_accuracy: 0.9180
# Epoch 7/50
# 194/194 [==============================] - 34s 175ms/step - loss: 0.3711 - accuracy: 0.8683 - val_loss: 0.1974 - val_accuracy: 0.9266
# Epoch 8/50
# 194/194 [==============================] - 34s 175ms/step - loss: 0.3510 - accuracy: 0.8754 - val_loss: 0.1892 - val_accuracy: 0.9229
# Epoch 9/50
# 194/194 [==============================] - 34s 173ms/step - loss: 0.3265 - accuracy: 0.8844 - val_loss: 0.1796 - val_accuracy: 0.9276
# Epoch 10/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.3125 - accuracy: 0.8884 - val_loss: 0.1786 - val_accuracy: 0.9278
# Epoch 11/50
# 194/194 [==============================] - 34s 175ms/step - loss: 0.2961 - accuracy: 0.8936 - val_loss: 0.1686 - val_accuracy: 0.9319
# Epoch 12/50
# 194/194 [==============================] - 34s 175ms/step - loss: 0.2827 - accuracy: 0.8988 - val_loss: 0.1668 - val_accuracy: 0.9342
# Epoch 13/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.2715 - accuracy: 0.9017 - val_loss: 0.1650 - val_accuracy: 0.9316
# Epoch 14/50
# 194/194 [==============================] - 34s 175ms/step - loss: 0.2622 - accuracy: 0.9041 - val_loss: 0.1556 - val_accuracy: 0.9381
# Epoch 15/50
# 194/194 [==============================] - 34s 173ms/step - loss: 0.2563 - accuracy: 0.9080 - val_loss: 0.1537 - val_accuracy: 0.9371
# Epoch 16/50
# 194/194 [==============================] - 34s 175ms/step - loss: 0.2464 - accuracy: 0.9101 - val_loss: 0.1506 - val_accuracy: 0.9427
# Epoch 17/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.2385 - accuracy: 0.9138 - val_loss: 0.1511 - val_accuracy: 0.9365
# Epoch 18/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.2337 - accuracy: 0.9143 - val_loss: 0.1420 - val_accuracy: 0.9437
# Epoch 19/50
# 194/194 [==============================] - 34s 175ms/step - loss: 0.2266 - accuracy: 0.9174 - val_loss: 0.1426 - val_accuracy: 0.9410
# Epoch 20/50
# 194/194 [==============================] - 34s 173ms/step - loss: 0.2204 - accuracy: 0.9191 - val_loss: 0.1407 - val_accuracy: 0.9460
# Epoch 21/50
# 194/194 [==============================] - 34s 176ms/step - loss: 0.2149 - accuracy: 0.9224 - val_loss: 0.1371 - val_accuracy: 0.9489
# Epoch 22/50
# 194/194 [==============================] - 34s 173ms/step - loss: 0.2110 - accuracy: 0.9228 - val_loss: 0.1334 - val_accuracy: 0.9456
# Epoch 23/50
# 194/194 [==============================] - 34s 173ms/step - loss: 0.2050 - accuracy: 0.9252 - val_loss: 0.1338 - val_accuracy: 0.9446
# Epoch 24/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.2012 - accuracy: 0.9268 - val_loss: 0.1312 - val_accuracy: 0.9499
# Epoch 25/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.1981 - accuracy: 0.9270 - val_loss: 0.1283 - val_accuracy: 0.9504
# Epoch 26/50
# 194/194 [==============================] - 34s 176ms/step - loss: 0.1960 - accuracy: 0.9276 - val_loss: 0.1311 - val_accuracy: 0.9457
# Epoch 27/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.1873 - accuracy: 0.9319 - val_loss: 0.1249 - val_accuracy: 0.9527
# Epoch 28/50
# 194/194 [==============================] - 34s 175ms/step - loss: 0.1896 - accuracy: 0.9304 - val_loss: 0.1276 - val_accuracy: 0.9465
# Epoch 29/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.1834 - accuracy: 0.9333 - val_loss: 0.1230 - val_accuracy: 0.9498
# Epoch 30/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.1837 - accuracy: 0.9341 - val_loss: 0.1233 - val_accuracy: 0.9509
# Epoch 31/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.1828 - accuracy: 0.9335 - val_loss: 0.1257 - val_accuracy: 0.9484
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 32/50
# 194/194 [==============================] - 33s 173ms/step - loss: 0.1697 - accuracy: 0.9391 - val_loss: 0.1181 - val_accuracy: 0.9552
# Epoch 33/50
# 194/194 [==============================] - 34s 174ms/step - loss: 0.1635 - accuracy: 0.9407 - val_loss: 0.1167 - val_accuracy: 0.9557
# Epoch 34/50
# 194/194 [==============================] - 34s 175ms/step - loss: 0.1607 - accuracy: 0.9421 - val_loss: 0.1159 - val_accuracy: 0.9563
# Epoch 35/50
# 194/194 [==============================] - 34s 173ms/step - loss: 0.1602 - accuracy: 0.9417 - val_loss: 0.1153 - val_accuracy: 0.9564
# Epoch 36/50
# 194/194 [==============================] - 34s 176ms/step - loss: 0.1589 - accuracy: 0.9431 - val_loss: 0.1150 - val_accuracy: 0.9569
# Epoch 37/50
# 194/194 [==============================] - 35s 181ms/step - loss: 0.1559 - accuracy: 0.9439 - val_loss: 0.1143 - val_accuracy: 0.9562
# Epoch 38/50
# 194/194 [==============================] - 34s 177ms/step - loss: 0.1570 - accuracy: 0.9437 - val_loss: 0.1142 - val_accuracy: 0.9566
# Epoch 39/50
# 194/194 [==============================] - 34s 176ms/step - loss: 0.1572 - accuracy: 0.9436 - val_loss: 0.1138 - val_accuracy: 0.9569
# Epoch 40/50
# 194/194 [==============================] - 35s 179ms/step - loss: 0.1552 - accuracy: 0.9441 - val_loss: 0.1134 - val_accuracy: 0.9569
# Epoch 41/50
# 194/194 [==============================] - 35s 178ms/step - loss: 0.1555 - accuracy: 0.9441 - val_loss: 0.1126 - val_accuracy: 0.9565
# Epoch 42/50
# 194/194 [==============================] - 34s 177ms/step - loss: 0.1535 - accuracy: 0.9443 - val_loss: 0.1122 - val_accuracy: 0.9572
# Epoch 43/50
# 194/194 [==============================] - 34s 176ms/step - loss: 0.1515 - accuracy: 0.9449 - val_loss: 0.1119 - val_accuracy: 0.9572
# Epoch 44/50
# 194/194 [==============================] - 34s 176ms/step - loss: 0.1514 - accuracy: 0.9454 - val_loss: 0.1108 - val_accuracy: 0.9577
# Epoch 45/50
# 194/194 [==============================] - 34s 176ms/step - loss: 0.1526 - accuracy: 0.9450 - val_loss: 0.1110 - val_accuracy: 0.9575
# Epoch 46/50
# 194/194 [==============================] - 35s 180ms/step - loss: 0.1512 - accuracy: 0.9461 - val_loss: 0.1111 - val_accuracy: 0.9575
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 47/50
# 194/194 [==============================] - 38s 196ms/step - loss: 0.1524 - accuracy: 0.9451 - val_loss: 0.1104 - val_accuracy: 0.9577
# Epoch 48/50
# 194/194 [==============================] - 34s 176ms/step - loss: 0.1515 - accuracy: 0.9457 - val_loss: 0.1105 - val_accuracy: 0.9575
# Epoch 49/50
# 194/194 [==============================] - 34s 177ms/step - loss: 0.1494 - accuracy: 0.9467 - val_loss: 0.1104 - val_accuracy: 0.9576
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 50/50
# 194/194 [==============================] - 35s 178ms/step - loss: 0.1504 - accuracy: 0.9458 - val_loss: 0.1104 - val_accuracy: 0.9576
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# Epoch 1/50
# 194/194 [==============================] - 52s 217ms/step - loss: 1.5710 - accuracy: 0.4689 - val_loss: 0.6070 - val_accuracy: 0.8511
# Epoch 2/50
# 194/194 [==============================] - 37s 188ms/step - loss: 0.7404 - accuracy: 0.7407 - val_loss: 0.3458 - val_accuracy: 0.9059
# Epoch 3/50
# 194/194 [==============================] - 37s 193ms/step - loss: 0.5724 - accuracy: 0.8017 - val_loss: 0.2935 - val_accuracy: 0.9077
# Epoch 4/50
# 194/194 [==============================] - 38s 195ms/step - loss: 0.4895 - accuracy: 0.8317 - val_loss: 0.2452 - val_accuracy: 0.9169
# Epoch 5/50
# 194/194 [==============================] - 38s 196ms/step - loss: 0.4332 - accuracy: 0.8500 - val_loss: 0.2280 - val_accuracy: 0.9134
# Epoch 6/50
# 194/194 [==============================] - 38s 194ms/step - loss: 0.3921 - accuracy: 0.8649 - val_loss: 0.2228 - val_accuracy: 0.9131
# Epoch 7/50
# 194/194 [==============================] - 37s 192ms/step - loss: 0.3608 - accuracy: 0.8739 - val_loss: 0.2031 - val_accuracy: 0.9200
# Epoch 8/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.3389 - accuracy: 0.8813 - val_loss: 0.1880 - val_accuracy: 0.9289
# Epoch 9/50
# 194/194 [==============================] - 38s 194ms/step - loss: 0.3217 - accuracy: 0.8864 - val_loss: 0.1983 - val_accuracy: 0.9206
# Epoch 10/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.3034 - accuracy: 0.8915 - val_loss: 0.1839 - val_accuracy: 0.9260
# Epoch 11/50
# 194/194 [==============================] - 39s 199ms/step - loss: 0.2908 - accuracy: 0.8961 - val_loss: 0.1760 - val_accuracy: 0.9278
# Epoch 12/50
# 194/194 [==============================] - 39s 199ms/step - loss: 0.2790 - accuracy: 0.8993 - val_loss: 0.1795 - val_accuracy: 0.9267
# Epoch 13/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.2671 - accuracy: 0.9029 - val_loss: 0.1700 - val_accuracy: 0.9280
# Epoch 14/50
# 194/194 [==============================] - 38s 196ms/step - loss: 0.2611 - accuracy: 0.9053 - val_loss: 0.1644 - val_accuracy: 0.9301
# Epoch 15/50
# 194/194 [==============================] - 37s 188ms/step - loss: 0.2494 - accuracy: 0.9093 - val_loss: 0.1612 - val_accuracy: 0.9310
# Epoch 16/50
# 194/194 [==============================] - 38s 194ms/step - loss: 0.2407 - accuracy: 0.9132 - val_loss: 0.1630 - val_accuracy: 0.9307
# Epoch 17/50
# 194/194 [==============================] - 37s 189ms/step - loss: 0.2340 - accuracy: 0.9142 - val_loss: 0.1592 - val_accuracy: 0.9338
# Epoch 18/50
# 194/194 [==============================] - 39s 200ms/step - loss: 0.2276 - accuracy: 0.9160 - val_loss: 0.1523 - val_accuracy: 0.9351
# Epoch 19/50
# 194/194 [==============================] - 38s 197ms/step - loss: 0.2213 - accuracy: 0.9193 - val_loss: 0.1480 - val_accuracy: 0.9361
# Epoch 20/50
# 194/194 [==============================] - 38s 196ms/step - loss: 0.2175 - accuracy: 0.9197 - val_loss: 0.1459 - val_accuracy: 0.9378
# Epoch 21/50
# 194/194 [==============================] - 38s 194ms/step - loss: 0.2119 - accuracy: 0.9229 - val_loss: 0.1467 - val_accuracy: 0.9385
# Epoch 22/50
# 194/194 [==============================] - 39s 202ms/step - loss: 0.2045 - accuracy: 0.9247 - val_loss: 0.1484 - val_accuracy: 0.9354
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 23/50
# 194/194 [==============================] - 39s 203ms/step - loss: 0.1970 - accuracy: 0.9294 - val_loss: 0.1318 - val_accuracy: 0.9480
# Epoch 24/50
# 194/194 [==============================] - 37s 190ms/step - loss: 0.1907 - accuracy: 0.9312 - val_loss: 0.1320 - val_accuracy: 0.9487
# Epoch 25/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1867 - accuracy: 0.9318 - val_loss: 0.1311 - val_accuracy: 0.9495
# Epoch 26/50
# 194/194 [==============================] - 37s 191ms/step - loss: 0.1861 - accuracy: 0.9328 - val_loss: 0.1304 - val_accuracy: 0.9494
# Epoch 27/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1862 - accuracy: 0.9328 - val_loss: 0.1299 - val_accuracy: 0.9503
# Epoch 28/50
# 194/194 [==============================] - 39s 203ms/step - loss: 0.1828 - accuracy: 0.9331 - val_loss: 0.1294 - val_accuracy: 0.9499
# Epoch 29/50
# 194/194 [==============================] - 37s 189ms/step - loss: 0.1796 - accuracy: 0.9339 - val_loss: 0.1290 - val_accuracy: 0.9502
# Epoch 30/50
# 194/194 [==============================] - 37s 188ms/step - loss: 0.1807 - accuracy: 0.9336 - val_loss: 0.1284 - val_accuracy: 0.9506
# Epoch 31/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1789 - accuracy: 0.9353 - val_loss: 0.1276 - val_accuracy: 0.9512
# Epoch 32/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1782 - accuracy: 0.9355 - val_loss: 0.1274 - val_accuracy: 0.9507
# Epoch 33/50
# 194/194 [==============================] - 40s 205ms/step - loss: 0.1778 - accuracy: 0.9355 - val_loss: 0.1268 - val_accuracy: 0.9509
# Epoch 34/50
# 194/194 [==============================] - 37s 189ms/step - loss: 0.1756 - accuracy: 0.9360 - val_loss: 0.1263 - val_accuracy: 0.9508
# Epoch 35/50
# 194/194 [==============================] - 37s 189ms/step - loss: 0.1750 - accuracy: 0.9365 - val_loss: 0.1256 - val_accuracy: 0.9515
# Epoch 36/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1779 - accuracy: 0.9360 - val_loss: 0.1258 - val_accuracy: 0.9502
# Epoch 37/50
# 194/194 [==============================] - 38s 194ms/step - loss: 0.1739 - accuracy: 0.9371 - val_loss: 0.1251 - val_accuracy: 0.9519
# Epoch 38/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1747 - accuracy: 0.9364 - val_loss: 0.1251 - val_accuracy: 0.9517
# Epoch 39/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1742 - accuracy: 0.9371 - val_loss: 0.1246 - val_accuracy: 0.9519
# Epoch 40/50
# 194/194 [==============================] - 37s 190ms/step - loss: 0.1741 - accuracy: 0.9367 - val_loss: 0.1240 - val_accuracy: 0.9523
# Epoch 41/50
# 194/194 [==============================] - 37s 189ms/step - loss: 0.1739 - accuracy: 0.9372 - val_loss: 0.1236 - val_accuracy: 0.9520
# Epoch 42/50
# 194/194 [==============================] - 37s 193ms/step - loss: 0.1748 - accuracy: 0.9377 - val_loss: 0.1229 - val_accuracy: 0.9525
# Epoch 43/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.1709 - accuracy: 0.9381 - val_loss: 0.1228 - val_accuracy: 0.9522
# Epoch 44/50
# 194/194 [==============================] - 38s 195ms/step - loss: 0.1698 - accuracy: 0.9384 - val_loss: 0.1225 - val_accuracy: 0.9528
# Epoch 45/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1703 - accuracy: 0.9383 - val_loss: 0.1228 - val_accuracy: 0.9525
# Epoch 46/50
# 194/194 [==============================] - 40s 206ms/step - loss: 0.1675 - accuracy: 0.9388 - val_loss: 0.1222 - val_accuracy: 0.9529
# Epoch 47/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.1688 - accuracy: 0.9389 - val_loss: 0.1219 - val_accuracy: 0.9529
# Epoch 48/50
# 194/194 [==============================] - 38s 195ms/step - loss: 0.1684 - accuracy: 0.9390 - val_loss: 0.1219 - val_accuracy: 0.9527
# Epoch 49/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1670 - accuracy: 0.9396 - val_loss: 0.1213 - val_accuracy: 0.9529
# Epoch 50/50
# 194/194 [==============================] - 40s 205ms/step - loss: 0.1673 - accuracy: 0.9399 - val_loss: 0.1215 - val_accuracy: 0.9530
# Epoch 1/50
# 194/194 [==============================] - 51s 213ms/step - loss: 1.4806 - accuracy: 0.4912 - val_loss: 0.5550 - val_accuracy: 0.8048
# Epoch 2/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.7151 - accuracy: 0.7383 - val_loss: 0.3755 - val_accuracy: 0.8916
# Epoch 3/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.5647 - accuracy: 0.7976 - val_loss: 0.3149 - val_accuracy: 0.8881
# Epoch 4/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.4817 - accuracy: 0.8312 - val_loss: 0.2793 - val_accuracy: 0.8942
# Epoch 5/50
# 194/194 [==============================] - 35s 183ms/step - loss: 0.4234 - accuracy: 0.8533 - val_loss: 0.2511 - val_accuracy: 0.9063
# Epoch 6/50
# 194/194 [==============================] - 37s 192ms/step - loss: 0.3868 - accuracy: 0.8655 - val_loss: 0.2275 - val_accuracy: 0.9132
# Epoch 7/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.3618 - accuracy: 0.8722 - val_loss: 0.2048 - val_accuracy: 0.9171
# Epoch 8/50
# 194/194 [==============================] - 38s 195ms/step - loss: 0.3367 - accuracy: 0.8815 - val_loss: 0.1991 - val_accuracy: 0.9183
# Epoch 9/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.3179 - accuracy: 0.8864 - val_loss: 0.1860 - val_accuracy: 0.9257
# Epoch 10/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.2999 - accuracy: 0.8932 - val_loss: 0.1794 - val_accuracy: 0.9311
# Epoch 11/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.2874 - accuracy: 0.8965 - val_loss: 0.1761 - val_accuracy: 0.9297
# Epoch 12/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.2789 - accuracy: 0.8991 - val_loss: 0.1750 - val_accuracy: 0.9262
# Epoch 13/50
# 194/194 [==============================] - 37s 189ms/step - loss: 0.2695 - accuracy: 0.9025 - val_loss: 0.1670 - val_accuracy: 0.9337
# Epoch 14/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.2594 - accuracy: 0.9064 - val_loss: 0.1617 - val_accuracy: 0.9376
# Epoch 15/50
# 194/194 [==============================] - 39s 202ms/step - loss: 0.2491 - accuracy: 0.9099 - val_loss: 0.1603 - val_accuracy: 0.9379
# Epoch 16/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.2425 - accuracy: 0.9124 - val_loss: 0.1546 - val_accuracy: 0.9391
# Epoch 17/50
# 194/194 [==============================] - 38s 199ms/step - loss: 0.2368 - accuracy: 0.9140 - val_loss: 0.1534 - val_accuracy: 0.9408
# Epoch 18/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.2296 - accuracy: 0.9156 - val_loss: 0.1516 - val_accuracy: 0.9414
# Epoch 19/50
# 194/194 [==============================] - 37s 191ms/step - loss: 0.2230 - accuracy: 0.9185 - val_loss: 0.1473 - val_accuracy: 0.9426
# Epoch 20/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.2180 - accuracy: 0.9197 - val_loss: 0.1482 - val_accuracy: 0.9423
# Epoch 21/50
# 194/194 [==============================] - 41s 213ms/step - loss: 0.2108 - accuracy: 0.9229 - val_loss: 0.1454 - val_accuracy: 0.9452
# Epoch 22/50
# 194/194 [==============================] - 38s 194ms/step - loss: 0.2094 - accuracy: 0.9225 - val_loss: 0.1431 - val_accuracy: 0.9442
# Epoch 23/50
# 194/194 [==============================] - 39s 200ms/step - loss: 0.2025 - accuracy: 0.9260 - val_loss: 0.1424 - val_accuracy: 0.9461
# Epoch 24/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.2029 - accuracy: 0.9258 - val_loss: 0.1408 - val_accuracy: 0.9486
# Epoch 25/50
# 194/194 [==============================] - 40s 205ms/step - loss: 0.1996 - accuracy: 0.9278 - val_loss: 0.1398 - val_accuracy: 0.9466
# Epoch 26/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.1939 - accuracy: 0.9288 - val_loss: 0.1405 - val_accuracy: 0.9459
# Epoch 27/50
# 194/194 [==============================] - 38s 194ms/step - loss: 0.1899 - accuracy: 0.9299 - val_loss: 0.1372 - val_accuracy: 0.9479
# Epoch 28/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1860 - accuracy: 0.9334 - val_loss: 0.1373 - val_accuracy: 0.9460
# Epoch 29/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1817 - accuracy: 0.9326 - val_loss: 0.1306 - val_accuracy: 0.9496
# Epoch 30/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1803 - accuracy: 0.9338 - val_loss: 0.1303 - val_accuracy: 0.9505
# Epoch 31/50
# 194/194 [==============================] - 40s 205ms/step - loss: 0.1784 - accuracy: 0.9350 - val_loss: 0.1306 - val_accuracy: 0.9515
# Epoch 32/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1748 - accuracy: 0.9366 - val_loss: 0.1329 - val_accuracy: 0.9494
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 33/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1673 - accuracy: 0.9408 - val_loss: 0.1240 - val_accuracy: 0.9530
# Epoch 34/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.1594 - accuracy: 0.9422 - val_loss: 0.1230 - val_accuracy: 0.9533
# Epoch 35/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1568 - accuracy: 0.9432 - val_loss: 0.1230 - val_accuracy: 0.9533
# Epoch 36/50
# 194/194 [==============================] - 38s 196ms/step - loss: 0.1551 - accuracy: 0.9438 - val_loss: 0.1222 - val_accuracy: 0.9536
# Epoch 37/50
# 194/194 [==============================] - 37s 191ms/step - loss: 0.1539 - accuracy: 0.9440 - val_loss: 0.1218 - val_accuracy: 0.9537
# Epoch 38/50
# 194/194 [==============================] - 37s 193ms/step - loss: 0.1545 - accuracy: 0.9441 - val_loss: 0.1213 - val_accuracy: 0.9541
# Epoch 39/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1514 - accuracy: 0.9444 - val_loss: 0.1211 - val_accuracy: 0.9543
# Epoch 40/50
# 194/194 [==============================] - 38s 196ms/step - loss: 0.1514 - accuracy: 0.9453 - val_loss: 0.1205 - val_accuracy: 0.9543
# Epoch 41/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.1505 - accuracy: 0.9453 - val_loss: 0.1203 - val_accuracy: 0.9542
# Epoch 42/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1499 - accuracy: 0.9458 - val_loss: 0.1195 - val_accuracy: 0.9542
# Epoch 43/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1488 - accuracy: 0.9468 - val_loss: 0.1192 - val_accuracy: 0.9548
# Epoch 44/50
# 194/194 [==============================] - 38s 194ms/step - loss: 0.1480 - accuracy: 0.9463 - val_loss: 0.1191 - val_accuracy: 0.9552
# Epoch 45/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.1501 - accuracy: 0.9458 - val_loss: 0.1193 - val_accuracy: 0.9557
# Epoch 46/50
# 194/194 [==============================] - 38s 197ms/step - loss: 0.1463 - accuracy: 0.9467 - val_loss: 0.1186 - val_accuracy: 0.9558
# Epoch 47/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.1461 - accuracy: 0.9470 - val_loss: 0.1180 - val_accuracy: 0.9560
# Epoch 48/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1466 - accuracy: 0.9469 - val_loss: 0.1185 - val_accuracy: 0.9558
# Epoch 49/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.1455 - accuracy: 0.9474 - val_loss: 0.1182 - val_accuracy: 0.9560
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 50/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1451 - accuracy: 0.9478 - val_loss: 0.1181 - val_accuracy: 0.9558
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# Epoch 1/50
# 194/194 [==============================] - 52s 221ms/step - loss: 1.5621 - accuracy: 0.4440 - val_loss: 0.6453 - val_accuracy: 0.8054
# Epoch 2/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.7439 - accuracy: 0.7246 - val_loss: 0.3971 - val_accuracy: 0.8156
# Epoch 3/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.5731 - accuracy: 0.7922 - val_loss: 0.3121 - val_accuracy: 0.8828
# Epoch 4/50
# 194/194 [==============================] - 39s 203ms/step - loss: 0.4889 - accuracy: 0.8279 - val_loss: 0.2604 - val_accuracy: 0.8964
# Epoch 5/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.4286 - accuracy: 0.8506 - val_loss: 0.2244 - val_accuracy: 0.9099
# Epoch 6/50
# 194/194 [==============================] - 38s 194ms/step - loss: 0.3873 - accuracy: 0.8662 - val_loss: 0.2195 - val_accuracy: 0.9070
# Epoch 7/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.3610 - accuracy: 0.8744 - val_loss: 0.2030 - val_accuracy: 0.9188
# Epoch 8/50
# 194/194 [==============================] - 39s 202ms/step - loss: 0.3360 - accuracy: 0.8810 - val_loss: 0.1929 - val_accuracy: 0.9221
# Epoch 9/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.3142 - accuracy: 0.8880 - val_loss: 0.1805 - val_accuracy: 0.9289
# Epoch 10/50
# 194/194 [==============================] - 42s 218ms/step - loss: 0.3007 - accuracy: 0.8923 - val_loss: 0.1707 - val_accuracy: 0.9333
# Epoch 11/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.2885 - accuracy: 0.8974 - val_loss: 0.1744 - val_accuracy: 0.9273
# Epoch 12/50
# 194/194 [==============================] - 37s 189ms/step - loss: 0.2767 - accuracy: 0.9000 - val_loss: 0.1692 - val_accuracy: 0.9279
# Epoch 13/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.2671 - accuracy: 0.9052 - val_loss: 0.1614 - val_accuracy: 0.9334
# Epoch 14/50
# 194/194 [==============================] - 38s 196ms/step - loss: 0.2568 - accuracy: 0.9071 - val_loss: 0.1663 - val_accuracy: 0.9303
# Epoch 15/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.2505 - accuracy: 0.9088 - val_loss: 0.1537 - val_accuracy: 0.9375
# Epoch 16/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.2414 - accuracy: 0.9127 - val_loss: 0.1565 - val_accuracy: 0.9325
# Epoch 17/50
# 194/194 [==============================] - 38s 195ms/step - loss: 0.2322 - accuracy: 0.9149 - val_loss: 0.1486 - val_accuracy: 0.9409
# Epoch 18/50
# 194/194 [==============================] - 37s 188ms/step - loss: 0.2286 - accuracy: 0.9184 - val_loss: 0.1398 - val_accuracy: 0.9466
# Epoch 19/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.2228 - accuracy: 0.9195 - val_loss: 0.1464 - val_accuracy: 0.9378
# Epoch 20/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.2160 - accuracy: 0.9223 - val_loss: 0.1383 - val_accuracy: 0.9456
# Epoch 21/50
# 194/194 [==============================] - 37s 188ms/step - loss: 0.2095 - accuracy: 0.9247 - val_loss: 0.1379 - val_accuracy: 0.9448
# Epoch 22/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.2024 - accuracy: 0.9265 - val_loss: 0.1345 - val_accuracy: 0.9476
# Epoch 23/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.2030 - accuracy: 0.9268 - val_loss: 0.1296 - val_accuracy: 0.9493
# Epoch 24/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1966 - accuracy: 0.9285 - val_loss: 0.1496 - val_accuracy: 0.9390
# Epoch 25/50
# 194/194 [==============================] - 37s 190ms/step - loss: 0.1959 - accuracy: 0.9286 - val_loss: 0.1390 - val_accuracy: 0.9416
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 26/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.1823 - accuracy: 0.9345 - val_loss: 0.1252 - val_accuracy: 0.9529
# Epoch 27/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1765 - accuracy: 0.9358 - val_loss: 0.1241 - val_accuracy: 0.9530
# Epoch 28/50
# 194/194 [==============================] - 40s 204ms/step - loss: 0.1720 - accuracy: 0.9374 - val_loss: 0.1230 - val_accuracy: 0.9531
# Epoch 29/50
# 194/194 [==============================] - 37s 190ms/step - loss: 0.1738 - accuracy: 0.9377 - val_loss: 0.1223 - val_accuracy: 0.9532
# Epoch 30/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1716 - accuracy: 0.9380 - val_loss: 0.1216 - val_accuracy: 0.9542
# Epoch 31/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.1716 - accuracy: 0.9380 - val_loss: 0.1207 - val_accuracy: 0.9540
# Epoch 32/50
# 194/194 [==============================] - 38s 195ms/step - loss: 0.1713 - accuracy: 0.9386 - val_loss: 0.1208 - val_accuracy: 0.9539
# Epoch 33/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1686 - accuracy: 0.9395 - val_loss: 0.1203 - val_accuracy: 0.9543
# Epoch 34/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.1676 - accuracy: 0.9391 - val_loss: 0.1199 - val_accuracy: 0.9542
# Epoch 35/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.1643 - accuracy: 0.9406 - val_loss: 0.1194 - val_accuracy: 0.9547
# Epoch 36/50
# 194/194 [==============================] - 40s 204ms/step - loss: 0.1635 - accuracy: 0.9401 - val_loss: 0.1192 - val_accuracy: 0.9547
# Epoch 37/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1661 - accuracy: 0.9410 - val_loss: 0.1189 - val_accuracy: 0.9552
# Epoch 38/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1638 - accuracy: 0.9409 - val_loss: 0.1185 - val_accuracy: 0.9548
# Epoch 39/50
# 194/194 [==============================] - 40s 208ms/step - loss: 0.1649 - accuracy: 0.9408 - val_loss: 0.1182 - val_accuracy: 0.9544
# Epoch 40/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1624 - accuracy: 0.9410 - val_loss: 0.1178 - val_accuracy: 0.9548
# Epoch 41/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1613 - accuracy: 0.9418 - val_loss: 0.1175 - val_accuracy: 0.9549
# Epoch 42/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1621 - accuracy: 0.9426 - val_loss: 0.1172 - val_accuracy: 0.9556
# Epoch 43/50
# 194/194 [==============================] - 37s 191ms/step - loss: 0.1630 - accuracy: 0.9409 - val_loss: 0.1169 - val_accuracy: 0.9557
# Epoch 44/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1620 - accuracy: 0.9424 - val_loss: 0.1165 - val_accuracy: 0.9554
# Epoch 45/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.1592 - accuracy: 0.9424 - val_loss: 0.1161 - val_accuracy: 0.9562
# Epoch 46/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.1604 - accuracy: 0.9421 - val_loss: 0.1157 - val_accuracy: 0.9558
# Epoch 47/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1577 - accuracy: 0.9424 - val_loss: 0.1157 - val_accuracy: 0.9562
# Epoch 48/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.1587 - accuracy: 0.9414 - val_loss: 0.1159 - val_accuracy: 0.9558
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 49/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.1565 - accuracy: 0.9437 - val_loss: 0.1154 - val_accuracy: 0.9562
# Epoch 50/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.1538 - accuracy: 0.9445 - val_loss: 0.1156 - val_accuracy: 0.9560
# Epoch 1/50
# 194/194 [==============================] - 54s 227ms/step - loss: 1.4971 - accuracy: 0.4708 - val_loss: 0.6359 - val_accuracy: 0.7578
# Epoch 2/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.7282 - accuracy: 0.7333 - val_loss: 0.4209 - val_accuracy: 0.8624
# Epoch 3/50
# 194/194 [==============================] - 37s 192ms/step - loss: 0.5699 - accuracy: 0.7962 - val_loss: 0.3225 - val_accuracy: 0.8923
# Epoch 4/50
# 194/194 [==============================] - 38s 197ms/step - loss: 0.4833 - accuracy: 0.8322 - val_loss: 0.2669 - val_accuracy: 0.9057
# Epoch 5/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.4269 - accuracy: 0.8523 - val_loss: 0.2669 - val_accuracy: 0.8948
# Epoch 6/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.3883 - accuracy: 0.8649 - val_loss: 0.2200 - val_accuracy: 0.9160
# Epoch 7/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.3595 - accuracy: 0.8745 - val_loss: 0.2111 - val_accuracy: 0.9163
# Epoch 8/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.3338 - accuracy: 0.8826 - val_loss: 0.2051 - val_accuracy: 0.9168
# Epoch 9/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.3138 - accuracy: 0.8878 - val_loss: 0.1866 - val_accuracy: 0.9275
# Epoch 10/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.3011 - accuracy: 0.8931 - val_loss: 0.1841 - val_accuracy: 0.9260
# Epoch 11/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.2845 - accuracy: 0.8985 - val_loss: 0.1819 - val_accuracy: 0.9249
# Epoch 12/50
# 194/194 [==============================] - 36s 187ms/step - loss: 0.2737 - accuracy: 0.9024 - val_loss: 0.1761 - val_accuracy: 0.9265
# Epoch 13/50
# 194/194 [==============================] - 36s 183ms/step - loss: 0.2646 - accuracy: 0.9047 - val_loss: 0.1752 - val_accuracy: 0.9267
# Epoch 14/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.2565 - accuracy: 0.9062 - val_loss: 0.1686 - val_accuracy: 0.9304
# Epoch 15/50
# 194/194 [==============================] - 37s 191ms/step - loss: 0.2492 - accuracy: 0.9111 - val_loss: 0.1601 - val_accuracy: 0.9381
# Epoch 16/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.2373 - accuracy: 0.9142 - val_loss: 0.1562 - val_accuracy: 0.9388
# Epoch 17/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.2285 - accuracy: 0.9166 - val_loss: 0.1553 - val_accuracy: 0.9397
# Epoch 18/50
# 194/194 [==============================] - 36s 183ms/step - loss: 0.2257 - accuracy: 0.9184 - val_loss: 0.1593 - val_accuracy: 0.9385
# Epoch 19/50
# 194/194 [==============================] - 40s 206ms/step - loss: 0.2205 - accuracy: 0.9202 - val_loss: 0.1505 - val_accuracy: 0.9416
# Epoch 20/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.2121 - accuracy: 0.9231 - val_loss: 0.1517 - val_accuracy: 0.9417
# Epoch 21/50
# 194/194 [==============================] - 35s 182ms/step - loss: 0.2097 - accuracy: 0.9229 - val_loss: 0.1500 - val_accuracy: 0.9360
# Epoch 22/50
# 194/194 [==============================] - 35s 182ms/step - loss: 0.2077 - accuracy: 0.9243 - val_loss: 0.1428 - val_accuracy: 0.9444
# Epoch 23/50
# 194/194 [==============================] - 40s 208ms/step - loss: 0.1990 - accuracy: 0.9279 - val_loss: 0.1414 - val_accuracy: 0.9466
# Epoch 24/50
# 194/194 [==============================] - 36s 183ms/step - loss: 0.1978 - accuracy: 0.9280 - val_loss: 0.1477 - val_accuracy: 0.9377
# Epoch 25/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.1962 - accuracy: 0.9285 - val_loss: 0.1387 - val_accuracy: 0.9464
# Epoch 26/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.1915 - accuracy: 0.9297 - val_loss: 0.1380 - val_accuracy: 0.9464
# Epoch 27/50
# 194/194 [==============================] - 39s 204ms/step - loss: 0.1862 - accuracy: 0.9324 - val_loss: 0.1388 - val_accuracy: 0.9455
# Epoch 28/50
# 194/194 [==============================] - 36s 183ms/step - loss: 0.1824 - accuracy: 0.9338 - val_loss: 0.1364 - val_accuracy: 0.9487
# Epoch 29/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1772 - accuracy: 0.9352 - val_loss: 0.1392 - val_accuracy: 0.9433
# Epoch 30/50
# 194/194 [==============================] - 37s 189ms/step - loss: 0.1775 - accuracy: 0.9360 - val_loss: 0.1311 - val_accuracy: 0.9495
# Epoch 31/50
# 194/194 [==============================] - 36s 183ms/step - loss: 0.1770 - accuracy: 0.9365 - val_loss: 0.1330 - val_accuracy: 0.9499
# Epoch 32/50
# 194/194 [==============================] - 35s 183ms/step - loss: 0.1747 - accuracy: 0.9365 - val_loss: 0.1285 - val_accuracy: 0.9504
# Epoch 33/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.1722 - accuracy: 0.9378 - val_loss: 0.1279 - val_accuracy: 0.9505
# Epoch 34/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1683 - accuracy: 0.9390 - val_loss: 0.1280 - val_accuracy: 0.9514
# Epoch 35/50
# 194/194 [==============================] - 37s 191ms/step - loss: 0.1652 - accuracy: 0.9409 - val_loss: 0.1290 - val_accuracy: 0.9515
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 36/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.1569 - accuracy: 0.9444 - val_loss: 0.1236 - val_accuracy: 0.9542
# Epoch 37/50
# 194/194 [==============================] - 36s 186ms/step - loss: 0.1516 - accuracy: 0.9450 - val_loss: 0.1230 - val_accuracy: 0.9544
# Epoch 38/50
# 194/194 [==============================] - 35s 182ms/step - loss: 0.1504 - accuracy: 0.9465 - val_loss: 0.1226 - val_accuracy: 0.9544
# Epoch 39/50
# 194/194 [==============================] - 39s 200ms/step - loss: 0.1474 - accuracy: 0.9467 - val_loss: 0.1224 - val_accuracy: 0.9543
# Epoch 40/50
# 194/194 [==============================] - 35s 183ms/step - loss: 0.1477 - accuracy: 0.9475 - val_loss: 0.1218 - val_accuracy: 0.9547
# Epoch 41/50
# 194/194 [==============================] - 35s 182ms/step - loss: 0.1438 - accuracy: 0.9477 - val_loss: 0.1212 - val_accuracy: 0.9546
# Epoch 42/50
# 194/194 [==============================] - 35s 183ms/step - loss: 0.1451 - accuracy: 0.9478 - val_loss: 0.1210 - val_accuracy: 0.9542
# Epoch 43/50
# 194/194 [==============================] - 38s 197ms/step - loss: 0.1433 - accuracy: 0.9489 - val_loss: 0.1207 - val_accuracy: 0.9546
# Epoch 44/50
# 194/194 [==============================] - 36s 185ms/step - loss: 0.1428 - accuracy: 0.9487 - val_loss: 0.1206 - val_accuracy: 0.9551
# Epoch 45/50
# 194/194 [==============================] - 35s 183ms/step - loss: 0.1436 - accuracy: 0.9478 - val_loss: 0.1202 - val_accuracy: 0.9552
# Epoch 46/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.1439 - accuracy: 0.9484 - val_loss: 0.1201 - val_accuracy: 0.9551
# Epoch 47/50
# 194/194 [==============================] - 36s 188ms/step - loss: 0.1419 - accuracy: 0.9483 - val_loss: 0.1202 - val_accuracy: 0.9546
# Epoch 48/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.1418 - accuracy: 0.9494 - val_loss: 0.1199 - val_accuracy: 0.9553
# Epoch 49/50
# 194/194 [==============================] - 36s 184ms/step - loss: 0.1401 - accuracy: 0.9504 - val_loss: 0.1196 - val_accuracy: 0.9558
# Epoch 50/50
# 194/194 [==============================] - 37s 189ms/step - loss: 0.1434 - accuracy: 0.9492 - val_loss: 0.1194 - val_accuracy: 0.9552

# %% [markdown]
# # Submission

# %%
submissions = pd.read_csv('../input/tabular-playground-series-feb-2022/sample_submission.csv')
submissions['target'] = pd.DataFrame(
    np.array([arr for arr in preds]).mean(axis=0),columns=y.columns
).idxmax(axis=1).values.tolist()
submissions.to_csv('preds.csv', index=False)
