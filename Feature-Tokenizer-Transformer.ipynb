# %% [markdown]
# # Feature Tokenizer Transformer
# Featured in the paper [Revisiting Deep Learning Models for Tabular Data (2021, June)](https://arxiv.org/abs/2106.11959) Feature Tokenizer Transformer is a simple adaptation of the Transformer architecture for the tabular domain. In a nutshell, Feature Tokenizer Transformer transforms all features (categorical and numerical) to embeddings and applies a stack of Transformer layers to the embeddings. Thus, every Transformer layer operates on the feature level of one object.
#
# In this notebook we will be implementing Feature Tokenizer Transformer using TensorFlow 2 from scratch.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers as L
from tensorflow_addons.activations import sparsemax
from tensorflow.data import Dataset
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
import joblib

pd.options.display.max_columns = 300

# %% [markdown]
# # Data
# Loading the train and test csv files into `pandas.DataFrame` and splitting the columns as features and target.
#
# We will be using Stratified K folds as our local cross validation.

# %%
data = pd.read_csv('../input/tabular-playground-series-feb-2022/train.csv')
data = data.drop_duplicates(subset=data.columns[1:]).reset_index(drop=True)
print(data.shape)
data.head()
# Out:
# (123993, 288)
#    row_id     A0T0G0C10  A0T0G1C9  A0T0G2C8  A0T0G3C7  A0T0G4C6  A0T0G5C5  \
# 0       0 -9.536743e-07 -0.000010 -0.000043 -0.000114 -0.000200 -0.000240
# 1       1 -9.536743e-07 -0.000010 -0.000043  0.000886 -0.000200  0.000760
# 2       2 -9.536743e-07 -0.000002  0.000007  0.000129  0.000268  0.000270
# 3       3  4.632568e-08 -0.000006  0.000012  0.000245  0.000492  0.000522
# 4       4 -9.536743e-07 -0.000010 -0.000043 -0.000114 -0.000200 -0.000240
#
#    A0T0G6C4  A0T0G7C3  A0T0G8C2  A0T0G9C1     A0T0G10C0  A0T1G0C9  \
# 0 -0.000200 -0.000114 -0.000043 -0.000010 -9.536743e-07 -0.000010
# 1 -0.000200 -0.000114 -0.000043 -0.000010 -9.536743e-07 -0.000010
# 2  0.000243  0.000125  0.000001 -0.000007  4.632568e-08 -0.000004
# 3  0.000396  0.000197 -0.000003 -0.000007 -9.536743e-07 -0.000010
# 4 -0.000200 -0.000114 -0.000043 -0.000010 -9.536743e-07 -0.000010
#
#        A0T1G1C8  A0T1G2C7  A0T1G3C6  A0T1G4C5  A0T1G5C4  A0T1G6C3  A0T1G7C2  \
# 0 -8.583069e-05 -0.000343 -0.000801 -0.001202 -0.001202 -0.000801 -0.000343
# 1 -8.583069e-05 -0.000343  0.000199 -0.000202  0.001798 -0.000801 -0.000343
# 2  1.693115e-07  0.000008  0.000366  0.000766  0.000937  0.000632  0.000101
# 3 -1.783069e-05  0.000068  0.000722  0.001594  0.001913  0.001111  0.000247
# 4 -8.583069e-05 -0.000343 -0.000801 -0.001202 -0.001202 -0.000801 -0.000343
#
#    A0T1G8C1  A0T1G9C0      A0T2G0C8  A0T2G1C7  A0T2G2C6  A0T2G3C5  A0T2G4C4  \
# 0 -0.000086 -0.000010 -4.291534e-05 -0.000343 -0.001202 -0.002403 -0.003004
# 1 -0.000086 -0.000010 -4.291534e-05 -0.000343  0.001798 -0.000403  0.001996
# 2 -0.000021 -0.000008  8.465576e-08 -0.000080  0.000114  0.000710  0.001307
# 3 -0.000047 -0.000010 -1.891534e-05 -0.000138  0.000161  0.001345  0.002526
# 4 -0.000086 -0.000010 -4.291534e-05 -0.000343 -0.001202 -0.002403 -0.003004
#
#    A0T2G5C3  A0T2G6C2  A0T2G7C1  A0T2G8C0  A0T3G0C7  A0T3G1C6  A0T3G2C5  \
# 0 -0.002403 -0.001202 -0.000343 -0.000043 -0.000114 -0.000801 -0.002403
# 1  0.003597 -0.001202 -0.000343 -0.000043 -0.000114 -0.000801 -0.000403
# 2  0.001065  0.000375 -0.000017 -0.000017 -0.000014 -0.000094  0.000183
# 3  0.002155  0.000754 -0.000029 -0.000025 -0.000034 -0.000179  0.000345
# 4 -0.002403 -0.001202 -0.000343 -0.000043 -0.000114 -0.000801 -0
-0.000801 -0.000200 -0.000114 -0.000343 -0.000343 -0.000114
# 1  0.001199  0.001199  0.000800 -0.000114 -0.000343 -0.000343 -0.000114
# 2  0.000203  0.000238  0.000120  0.000027  0.000097  0.000159  0.000070
# 3  0.000401  0.000412  0.000246  0.000047  0.000160  0.000309  0.000129
# 4 -0.000801 -0.000801 -0.000200 -0.000114 -0.000343 -0.000343 -0.000114
#
#    A7T1G0C2  A7T1G1C1  A7T1G2C0  A7T2G0C1  A7T2G1C0  A7T3G0C0  A8T0G0C2  \
# 0 -0.000343 -0.000687 -0.000343 -0.000343 -0.000343 -0.000114 -0.000043
# 1 -0.000343  0.001313  0.000657  0.001657  0.001657  0.000886 -0.000043
# 2  0.000138  0.000315  0.000214  0.000178  0.000296  0.000118  0.000042
# 3  0.000243  0.000597  0.000428  0.000363  0.000472  0.000197  0.000068
# 4 -0.000343  0.009313 -0.000343 -0.000343  0.009657 -0.000114 -0.000043
#
#    A8T0G1C1  A8T0G2C0  A8T1G0C1  A8T1G1C0  A8T2G0C0  A9T0G0C1  A9T0G1C0  \
# 0 -0.000086 -0.000043 -0.000086 -0.000086 -0.000043 -0.000010 -0.000010
# 1 -0.000086 -0.000043  0.000914  0.000914 -0.000043 -0.000010 -0.000010
# 2  0.000084  0.000048  0.000081  0.000106  0.000072  0.000010  0.000008
# 3  0.000151  0.000100  0.000180  0.000202  0.000153  0.000021  0.000015
# 4 -0.000086 -0.000043 -0.000086 -0.000086 -0.000043 -0.000010 -0.000010
#
#    A9T1G0C0     A10T0G0C0                  target
# 0 -0.000010 -9.536743e-07  Streptococcus_pyogenes
# 1 -0.000010 -9.536743e-07     Salmonella_enterica
# 2  0.000019  1.046326e-06     Salmonella_enterica
# 3  0.000046 -9.536743e-07     Salmonella_enterica
# 4 -0.000010 -9.536743e-07      Enterococcus_hirae

# %%
test = pd.read_csv('../input/tabular-playground-series-feb-2022/test.csv')
print(test.shape)
X_test = test.drop(['row_id'], axis=1)
# Out:
# (100000, 287)

# %%
X = data.drop(['row_id', 'target'], axis=1)
y = pd.get_dummies(data['target'])

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# # Model
# **Creating some data utility classes**:
#
# `DataConfig` helps to segregate the features into numeric features and categorical features and maintain a vocabulary for the categorical ones.
#
# `DataLoader` class creates `tf.data.Dataset` objects from `pandas.DataFrame` to ensure efficiency in the input pipeline to the model.

# %%
class DataConfig:
    def __init__(self, numeric_feature_names, categorical_features_with_vocabulary):
        self.NUMERIC_FEATURE_NAMES = numeric_feature_names
        self.CATEGORICAL_FEATURES_WITH_VOCABULARY = categorical_features_with_vocabulary
        self.CATEGORICAL_FEATURE_NAMES = list(self.CATEGORICAL_FEATURES_WITH_VOCABULARY.keys())
        self.FEATURE_NAMES = self.NUMERIC_FEATURE_NAMES + self.CATEGORICAL_FEATURE_NAMES
        
class DataLoader:
    @classmethod
    def from_df(cls, X, y=None, batch_size=1024):
        return (
            Dataset.from_tensor_slices(({col: X[col].values.tolist() for col in X.columns}, y.values.tolist())).batch(
                batch_size
            )
            if y is not None
            else Dataset.from_tensor_slices({col: X[col].values.tolist() for col in X.columns}).batch(batch_size)
        )

# %% [markdown]
# **Creating Input Layers and Feature Encoding Layers**
#
# `get_inputs` returns a dictionary of Input Layers based on the data types of the feature columns mentioned in the `DataConfig` object.
#
# `encode_inputs` applies StringLookup and Embedding Layer to the categorical features and Reshapes the Numeric Features in order to encode the inputs.

# %%
def get_inputs(config):
    return {
        feature_name: L.Input(
            name=feature_name,
            shape=(),
            dtype=(tf.float32 if feature_name in config.NUMERIC_FEATURE_NAMES else tf.string),
        )
        for feature_name in config.FEATURE_NAMES
    }

def encode_inputs(inputs, config, use_embeddings=False, embedding_dim=32, prefix="", concat_features=False):
    cat_features = []
    num_features = []
    for feature_name in inputs:
        if feature_name in config.CATEGORICAL_FEATURE_NAMES:
            vocabulary = config.CATEGORICAL_FEATURES_WITH_VOCABULARY[feature_name]
            lookup = L.StringLookup(
                vocabulary=vocabulary,
                mask_token=None,
                num_oov_indices=0,
                output_mode="int" if use_embeddings else "binary",
                name=f"{prefix}{feature_name}_lookup",
            )
            if use_embeddings:
                encoded_feature = lookup(inputs[feature_name])
                embedding = L.Embedding(
                    input_dim=len(vocabulary),
                    output_dim=embedding_dim,
                    name=f"{prefix}{feature_name}_embeddings",
                )
                encoded_feature = embedding(encoded_feature)
            else:
                encoded_feature = lookup(
                    L.Reshape((1,), name=f"{prefix}{feature_name}_reshape")(inputs[feature_name])
                )
            cat_features.append(encoded_feature)
        else:
            encoded_feature = L.Reshape((1,), name=f"{prefix}{feature_name}_reshape")(inputs[feature_name])
            num_features.append(encoded_feature)

    features = (
        L.Concatenate(name=f"{prefix}inputs_concatenate")(cat_features + num_features)
        if concat_features
        else (cat_features, num_features)
    )

    return features

# %% [markdown]
# **Defining Model Configurations**
# * Number of Outputs
# * Activation of the Output Layer
# * Number of Transformer Blocks
# * Number of heads in the Transformer Blocks
# * Embedding Dimension for the features
# * Dimesion of the Dense Projections in the transfomer blocks

# %%
class FeatureTokenizerTransformerConfig:
    def __init__(
        self,
        num_outputs,
        out_activation,
        num_transformer_blocks=2,
        num_heads=8,
        embedding_dim=32,
        dense_dim=16,
    ):
        self.NUM_OUT = num_outputs
        self.OUT_ACTIVATION = out_activation
        self.NUM_TRANSFORMER_BLOCKS = num_transformer_blocks
        self.NUM_HEADS = num_heads
        self.EMBEDDING_DIM = embedding_dim
        self.DENSE_DIM = dense_dim

# %% [markdown]
# **Defining a standard Transformer Block**

# %%
class TransformerBlock(L.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = L.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = tf.keras.Sequential([L.Dense(dense_dim, activation="relu"), L.Dense(embed_dim)])
        self.layernorm1 = L.LayerNormalization()
        self.layernorm2 = L.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[: tf.newaxis, :]
        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm2(proj_input + proj_output)

# %% [markdown]
# **Defining the Model**
# The model takes Inputs Layers and then encodes the features from the functions defined above, the numerical features are then passed through a Dense layer of the same dimensions as the embeddings of the categorical features.
#
# All the feature embeddings are then stacked and then passed through a series of Transformer Blocks followed by the Global Average Pooling and Final Output Layer

# %%
class FeatureTokenizerTransformer:
    @classmethod
    def from_config(cls, data_config, model_config, name):
        inputs = get_inputs(data_config)
        cat_features, num_features = encode_inputs(
            inputs,
            data_config,
            use_embeddings=True,
            embedding_dim=model_config.EMBEDDING_DIM,
            prefix="",
            concat_features=False,
        )
        num_feat_emb = [
            L.Dense(model_config.EMBEDDING_DIM, name=f"{feature_name}_embeddings")
            for _, feature_name in zip(range(len(num_features)), data_config.NUMERIC_FEATURE_NAMES)
        ]
        num_features = [emb(feat) for emb, feat in zip(num_feat_emb, num_features)]

        features = L.Concatenate(axis=1, name="feature_embeddings_stack")(
            [
                L.Reshape((1, 32), name=f"{feat_name}_reshape_2")(feat)
                for feat, feat_name in zip((num_features + cat_features), data_config.FEATURE_NAMES)
            ]
        )

        for _ in range(model_config.NUM_TRANSFORMER_BLOCKS):
            features = TransformerBlock(
                embed_dim=model_config.EMBEDDING_DIM,
                dense_dim=model_config.DENSE_DIM,
                num_heads=model_config.NUM_HEADS,
            )(features)
        features = L.GlobalMaxPooling1D()(features)
        outputs = L.Dense(
            units=model_config.NUM_OUT,
            activation=model_config.OUT_ACTIVATION,
            name="outputs",
        )(features)
        model = keras.Model(inputs=inputs, outputs=outputs, name=name)
        return model

# %% [markdown]
# **Creating instances of the various classes defined so far**

# %%
data_config = DataConfig(
    numeric_feature_names=X.columns.tolist(), categorical_features_with_vocabulary={}
)
model_config = FeatureTokenizerTransformerConfig(num_outputs=len(y.columns), out_activation='softmax')

# %%
blank_model = FeatureTokenizerTransformer.from_config(data_config, model_config, name='ftt')
blank_model.summary()
# Out:
# 2022-03-31 14:05:31.911963: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 14:05:32.048224: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 14:05:32.049350: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 14:05:32.051022: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-31 14:05:32.052104: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 14:05:32.053050: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 14:05:32.054044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 14:05:34.179569: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 14:05:34.180677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 14:05:34.181606: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-31 14:05:34.182562: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "ftt"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# A0T0G0C10 (InputLayer)          [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G1C9 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G2C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G3C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G4C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G5C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G6C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G7C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G8C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G9C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T0G10C0 (InputLayer)          [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G0C9 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G1C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G2C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G3C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G4C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G5C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G6C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G7C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G8C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T1G9C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G0C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G1C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G2C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G3C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G4C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G5C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G6C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G7C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T2G8C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G0C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G1C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G2C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G3C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G4C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G5C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G6C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T3G7C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G0C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G1C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G2C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G3C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G4C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G5C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T4G6C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T5G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T6G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T6G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T6G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T6G3C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T6G4C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T7G0C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T7G1C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T7G2C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T7G3C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T8G0C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T8G1C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T8G2C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T9G0C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T9G1C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A0T10G0C0 (InputLayer)          [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G0C9 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G1C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G2C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G3C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G4C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G5C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G6C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G7C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G8C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T0G9C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G0C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G1C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G2C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G3C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G4C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G5C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G6C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G7C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T1G8C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G0C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G1C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G2C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G3C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G4C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G5C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G6C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T2G7C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G0C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G1C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G2C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G3C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G4C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G5C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T3G6C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T4G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T5G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T5G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T5G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T5G3C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T5G4C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T6G0C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T6G1C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T6G2C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T6G3C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T7G0C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T7G1C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T7G2C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T8G0C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T8G1C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A1T9G0C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G0C8 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G1C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G2C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G3C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G4C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G5C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G6C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G7C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T0G8C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G0C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G1C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G2C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G3C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G4C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G5C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G6C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T1G7C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G0C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G1C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G2C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G3C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G4C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G5C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T2G6C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T3G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T4G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T4G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T4G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T4G3C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T4G4C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T5G0C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T5G1C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T5G2C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T5G3C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T6G0C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T6G1C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T6G2C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T7G0C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T7G1C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A2T8G0C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G0C7 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G1C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G2C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G3C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G4C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G5C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G6C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T0G7C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G0C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G1C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G2C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G3C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G4C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G5C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T1G6C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T2G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T3G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T3G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T3G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T3G3C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T3G4C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T4G0C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T4G1C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T4G2C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T4G3C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T5G0C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T5G1C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T5G2C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T6G0C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T6G1C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A3T7G0C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G0C6 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G1C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G2C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G3C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G4C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G5C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T0G6C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G0C5 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G1C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G2C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G3C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G4C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T1G5C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T2G0C4 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T2G1C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T2G2C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T2G3C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T2G4C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T3G0C3 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T3G1C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T3G2C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T3G3C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T4G0C2 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T4G1C1 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T4G2C0 (InputLayer)           [(None,)]            0
# __________________________________________________________________________________________________
# A4T5G0C1 (InputLayer)           [(None,)]            0
# ...
#                                                                  A2T1G6C1_reshape_2[0][0]
#                                                                  A2T1G7C0_reshape_2[0][0]
#                                                                  A2T2G0C6_reshape_2[0][0]
#                                                                  A2T2G1C5_reshape_2[0][0]
#                                                                  A2T2G2C4_reshape_2[0][0]
#                                                                  A2T2G3C3_reshape_2[0][0]
#                                                                  A2T2G4C2_reshape_2[0][0]
#                                                                  A2T2G5C1_reshape_2[0][0]
#                                                                  A2T2G6C0_reshape_2[0][0]
#                                                                  A2T3G0C5_reshape_2[0][0]
#                                                                  A2T3G1C4_reshape_2[0][0]
#                                                                  A2T3G2C3_reshape_2[0][0]
#                                                                  A2T3G3C2_reshape_2[0][0]
#                                                                  A2T3G4C1_reshape_2[0][0]
#                                                                  A2T3G5C0_reshape_2[0][0]
#                                                                  A2T4G0C4_reshape_2[0][0]
#                                                                  A2T4G1C3_reshape_2[0][0]
#                                                                  A2T4G2C2_reshape_2[0][0]
#                                                                  A2T4G3C1_reshape_2[0][0]
#                                                                  A2T4G4C0_reshape_2[0][0]
#                                                                  A2T5G0C3_reshape_2[0][0]
#                                                                  A2T5G1C2_reshape_2[0][0]
#                                                                  A2T5G2C1_reshape_2[0][0]
#                                                                  A2T5G3C0_reshape_2[0][0]
#                                                                  A2T6G0C2_reshape_2[0][0]
#                                                                  A2T6G1C1_reshape_2[0][0]
#                                                                  A2T6G2C0_reshape_2[0][0]
#                                                                  A2T7G0C1_reshape_2[0][0]
#                                                                  A2T7G1C0_reshape_2[0][0]
#                                                                  A2T8G0C0_reshape_2[0][0]
#                                                                  A3T0G0C7_reshape_2[0][0]
#                                                                  A3T0G1C6_reshape_2[0][0]
#                                                                  A3T0G2C5_reshape_2[0][0]
#                                                                  A3T0G3C4_reshape_2[0][0]
#                                                                  A3T0G4C3_reshape_2[0][0]
#                                                                  A3T0G5C2_reshape_2[0][0]
#                                                                  A3T0G6C1_reshape_2[0][0]
#                                                                  A3T0G7C0_reshape_2[0][0]
#                                                                  A3T1G0C6_reshape_2[0][0]
#                                                                  A3T1G1C5_reshape_2[0][0]
#                                                                  A3T1G2C4_reshape_2[0][0]
#                                                                  A3T1G3C3_reshape_2[0][0]
#                                                                  A3T1G4C2_reshape_2[0][0]
#                                                                  A3T1G5C1_reshape_2[0][0]
#                                                                  A3T1G6C0_reshape_2[0][0]
#                                                                  A3T2G0C5_reshape_2[0][0]
#                                                                  A3T2G1C4_reshape_2[0][0]
#                                                                  A3T2G2C3_reshape_2[0][0]
#                                                                  A3T2G3C2_reshape_2[0][0]
#                                                                  A3T2G4C1_reshape_2[0][0]
#                                                                  A3T2G5C0_reshape_2[0][0]
#                                                                  A3T3G0C4_reshape_2[0][0]
#                                                                  A3T3G1C3_reshape_2[0][0]
#                                                                  A3T3G2C2_reshape_2[0][0]
#                                                                  A3T3G3C1_reshape_2[0][0]
#                                                                  A3T3G4C0_reshape_2[0][0]
#                                                                  A3T4G0C3_reshape_2[0][0]
#                                                                  A3T4G1C2_reshape_2[0][0]
#                                                                  A3T4G2C1_reshape_2[0][0]
#                                                                  A3T4G3C0_reshape_2[0][0]
#                                                                  A3T5G0C2_reshape_2[0][0]
#                                                                  A3T5G1C1_reshape_2[0][0]
#                                                                  A3T5G2C0_reshape_2[0][0]
#                                                                  A3T6G0C1_reshape_2[0][0]
#                                                                  A3T6G1C0_reshape_2[0][0]
#                                                                  A3T7G0C0_reshape_2[0][0]
#                                                                  A4T0G0C6_reshape_2[0][0]
#                                                                  A4T0G1C5_reshape_2[0][0]
#                                                                  A4T0G2C4_reshape_2[0][0]
#                                                                  A4T0G3C3_reshape_2[0][0]
#                                                                  A4T0G4C2_reshape_2[0][0]
#                                                                  A4T0G5C1_reshape_2[0][0]
#                                                                  A4T0G6C0_reshape_2[0][0]
#                                                                  A4T1G0C5_reshape_2[0][0]
#                                                                  A4T1G1C4_reshape_2[0][0]
#                                                                  A4T1G2C3_reshape_2[0][0]
#                                                                  A4T1G3C2_reshape_2[0][0]
#                                                                  A4T1G4C1_reshape_2[0][0]
#                                                                  A4T1G5C0_reshape_2[0][0]
#                                                                  A4T2G0C4_reshape_2[0][0]
#                                                                  A4T2G1C3_reshape_2[0][0]
#                                                                  A4T2G2C2_reshape_2[0][0]
#                                                                  A4T2G3C1_reshape_2[0][0]
#                                                                  A4T2G4C0_reshape_2[0][0]
#                                                                  A4T3G0C3_reshape_2[0][0]
#                                                                  A4T3G1C2_reshape_2[0][0]
#                                                                  A4T3G2C1_reshape_2[0][0]
#                                                                  A4T3G3C0_reshape_2[0][0]
#                                                                  A4T4G0C2_reshape_2[0][0]
#                                                                  A4T4G1C1_reshape_2[0][0]
#                                                                  A4T4G2C0_reshape_2[0][0]
#                                                                  A4T5G0C1_reshape_2[0][0]
#                                                                  A4T5G1C0_reshape_2[0][0]
#                                                                  A4T6G0C0_reshape_2[0][0]
#                                                                  A5T0G0C5_reshape_2[0][0]
#                                                                  A5T0G1C4_reshape_2[0][0]
#                                                                  A5T0G2C3_reshape_2[0][0]
#                                                                  A5T0G3C2_reshape_2[0][0]
#                                                                  A5T0G4C1_reshape_2[0][0]
#                                                                  A5T0G5C0_reshape_2[0][0]
#                                                                  A5T1G0C4_reshape_2[0][0]
#                                                                  A5T1G1C3_reshape_2[0][0]
#                                                                  A5T1G2C2_reshape_2[0][0]
#                                                                  A5T1G3C1_reshape_2[0][0]
#                                                                  A5T1G4C0_reshape_2[0][0]
#                                                                  A5T2G0C3_reshape_2[0][0]
#                                                                  A5T2G1C2_reshape_2[0][0]
#                                                                  A5T2G2C1_reshape_2[0][0]
#                                                                  A5T2G3C0_reshape_2[0][0]
#                                                                  A5T3G0C2_reshape_2[0][0]
#                                                                  A5T3G1C1_reshape_2[0][0]
#                                                                  A5T3G2C0_reshape_2[0][0]
#                                                                  A5T4G0C1_reshape_2[0][0]
#                                                                  A5T4G1C0_reshape_2[0][0]
#                                                                  A5T5G0C0_reshape_2[0][0]
#                                                                  A6T0G0C4_reshape_2[0][0]
#                                                                  A6T0G1C3_reshape_2[0][0]
#                                                                  A6T0G2C2_reshape_2[0][0]
#                                                                  A6T0G3C1_reshape_2[0][0]
#                                                                  A6T0G4C0_reshape_2[0][0]
#                                                                  A6T1G0C3_reshape_2[0][0]
#                                                                  A6T1G1C2_reshape_2[0][0]
#                                                                  A6T1G2C1_reshape_2[0][0]
#                                                                  A6T1G3C0_reshape_2[0][0]
#                                                                  A6T2G0C2_reshape_2[0][0]
#                                                                  A6T2G1C1_reshape_2[0][0]
#                                                                  A6T2G2C0_reshape_2[0][0]
#                                                                  A6T3G0C1_reshape_2[0][0]
#                                                                  A6T3G1C0_reshape_2[0][0]
#                                                                  A6T4G0C0_reshape_2[0][0]
#                                                                  A7T0G0C3_reshape_2[0][0]
#                                                                  A7T0G1C2_reshape_2[0][0]
#                                                                  A7T0G2C1_reshape_2[0][0]
#                                                                  A7T0G3C0_reshape_2[0][0]
#                                                                  A7T1G0C2_reshape_2[0][0]
#                                                                  A7T1G1C1_reshape_2[0][0]
#                                                                  A7T1G2C0_reshape_2[0][0]
#                                                                  A7T2G0C1_reshape_2[0][0]
#                                                                  A7T2G1C0_reshape_2[0][0]
#                                                                  A7T3G0C0_reshape_2[0][0]
#                                                                  A8T0G0C2_reshape_2[0][0]
#                                                                  A8T0G1C1_reshape_2[0][0]
#                                                                  A8T0G2C0_reshape_2[0][0]
#                                                                  A8T1G0C1_reshape_2[0][0]
#                                                                  A8T1G1C0_reshape_2[0][0]
#                                                                  A8T2G0C0_reshape_2[0][0]
#                                                                  A9T0G0C1_reshape_2[0][0]
#                                                                  A9T0G1C0_reshape_2[0][0]
#                                                                  A9T1G0C0_reshape_2[0][0]
#                                                                  A10T0G0C0_reshape_2[0][0]
# __________________________________________________________________________________________________
# transformer_block (TransformerB (None, 286, 32)      34768       feature_embeddings_stack[0][0]
# __________________________________________________________________________________________________
# transformer_block_1 (Transforme (None, 286, 32)      34768       transformer_block[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 32)           0           transformer_block_1[0][0]
# __________________________________________________________________________________________________
# outputs (Dense)                 (None, 10)           330         global_max_pooling1d[0][0]
# ==================================================================================================
# Total params: 88,170
# Trainable params: 88,170
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
MAX_EPOCHS  = 50

get_callbacks = lambda : [
    keras.callbacks.EarlyStopping(min_delta=1e-4, patience=3, verbose=1, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(patience=2, verbose=1)
]

# %% [markdown]
# # Training Loop

# %%
preds = []

for fold, (train_index, valid_index) in enumerate(skf.split(X, data['target'])):
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
    
    scaler = StandardScaler().fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
    X_valid = pd.DataFrame(scaler.transform(X_valid), columns=X.columns)
    x_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)
    
    data_train = DataLoader.from_df(X_train, y_train, batch_size=512)
    data_valid = DataLoader.from_df(X_valid, y_valid, batch_size=512)
    data_test = DataLoader.from_df(x_test, batch_size=512)
    
    model = FeatureTokenizerTransformer.from_config(data_config, model_config, name=f'ftt_fold_{fold}')
    model.compile(
        loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy']
    )
    model.fit(
        data_train, validation_data=data_valid, callbacks=get_callbacks(), 
        epochs=MAX_EPOCHS
    )  
    preds.append(model.predict(data_test))
# Out:
# Epoch 1/50
# 2022-03-31 14:10:37.033886: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-03-31 14:10:43.890460: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 194/194 [==============================] - 134s 557ms/step - loss: 1.0342 - accuracy: 0.6919 - val_loss: 0.4798 - val_accuracy: 0.8300
# Epoch 2/50
# 194/194 [==============================] - 101s 518ms/step - loss: 0.3517 - accuracy: 0.8800 - val_loss: 0.2798 - val_accuracy: 0.8993
# Epoch 3/50
# 194/194 [==============================] - 99s 511ms/step - loss: 0.2615 - accuracy: 0.9029 - val_loss: 0.2364 - val_accuracy: 0.9102
# Epoch 4/50
# 194/194 [==============================] - 97s 500ms/step - loss: 0.2379 - accuracy: 0.9088 - val_loss: 0.2200 - val_accuracy: 0.9162
# Epoch 5/50
# 194/194 [==============================] - 98s 504ms/step - loss: 0.2115 - accuracy: 0.9172 - val_loss: 0.2472 - val_accuracy: 0.9062
# Epoch 6/50
# 194/194 [==============================] - 100s 516ms/step - loss: 0
# Epoch 33/50
# 194/194 [==============================] - 105s 543ms/step - loss: 0.0751 - accuracy: 0.9743 - val_loss: 0.1302 - val_accuracy: 0.9497
# Epoch 34/50
# 194/194 [==============================] - 100s 515ms/step - loss: 0.0744 - accuracy: 0.9748 - val_loss: 0.1301 - val_accuracy: 0.9493
# Epoch 35/50
# 194/194 [==============================] - 106s 548ms/step - loss: 0.0737 - accuracy: 0.9749 - val_loss: 0.1300 - val_accuracy: 0.9497
# Epoch 36/50
# 194/194 [==============================] - 105s 540ms/step - loss: 0.0730 - accuracy: 0.9753 - val_loss: 0.1298 - val_accuracy: 0.9498
# Epoch 37/50
# 194/194 [==============================] - 105s 542ms/step - loss: 0.0723 - accuracy: 0.9756 - val_loss: 0.1297 - val_accuracy: 0.9501
# Epoch 38/50
# 194/194 [==============================] - 98s 507ms/step - loss: 0.0717 - accuracy: 0.9760 - val_loss: 0.1296 - val_accuracy: 0.9501
# Epoch 39/50
# 194/194 [==============================] - 105s 541ms/step - loss: 0.0710 - accuracy: 0.9763 - val_loss: 0.1294 - val_accuracy: 0.9501
# Epoch 40/50
# 194/194 [==============================] - 106s 545ms/step - loss: 0.0704 - accuracy: 0.9765 - val_loss: 0.1293 - val_accuracy: 0.9503
# Epoch 41/50
# 194/194 [==============================] - 106s 547ms/step - loss: 0.0698 - accuracy: 0.9767 - val_loss: 0.1291 - val_accuracy: 0.9503
# Epoch 42/50
# 194/194 [==============================] - 106s 545ms/step - loss: 0.0691 - accuracy: 0.9770 - val_loss: 0.1290 - val_accuracy: 0.9503
# Epoch 43/50
# 194/194 [==============================] - 98s 507ms/step - loss: 0.0685 - accuracy: 0.9774 - val_loss: 0.1291 - val_accuracy: 0.9500
# Epoch 44/50
# 194/194 [==============================] - 106s 547ms/step - loss: 0.0679 - accuracy: 0.9776 - val_loss: 0.1289 - val_accuracy: 0.9503
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 45/50
# 194/194 [==============================] - 106s 546ms/step - loss: 0.0663 - accuracy: 0.9783 - val_loss: 0.1266 - val_accuracy: 0.9516
# Epoch 46/50
# 194/194 [==============================] - 106s 545ms/step - loss: 0.0656 - accuracy: 0.9786 - val_loss: 0.1265 - val_accuracy: 0.9512
# Epoch 47/50
# 194/194 [==============================] - 99s 508ms/step - loss: 0.0654 - accuracy: 0.9785 - val_loss: 0.1265 - val_accuracy: 0.9512
# Epoch 48/50
# 194/194 [==============================] - 105s 543ms/step - loss: 0.0652 - accuracy: 0.9786 - val_loss: 0.1264 - val_accuracy: 0.9511
# Epoch 49/50
# 194/194 [==============================] - 105s 544ms/step - loss: 0.0651 - accuracy: 0.9786 - val_loss: 0.1264 - val_accuracy: 0.9511
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 50/50
# 194/194 [==============================] - 99s 509ms/step - loss: 0.0646 - accuracy: 0.9790 - val_loss: 0.1264 - val_accuracy: 0.9510
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping

# %% [markdown]
# # Submission

# %%
submissions = pd.read_csv('../input/tabular-playground-series-feb-2022/sample_submission.csv')
submissions['target'] = pd.DataFrame(
    np.array([arr for arr in preds]).mean(axis=0),columns=y.columns
).idxmax(axis=1).values.tolist()
submissions.to_csv('preds.csv', index=False)
