# %% [markdown]
# # Deep Neural Decision Forests
#
# Even though deep learning has attained trendendous success on data domains such as images, audio and texts.
# GDBT still rule the domain of tabular data.
#
# In this note we will discuss [Deep Neural Decision Forests](https://ieeexplore.ieee.org/document/7410529) for tabular deep learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers as L

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
import joblib

# %% [markdown]
# # Data

# %%
data = pd.read_csv('../input/song-popularity-prediction/train.csv')
print(data.shape)
data.head()
# Out:
# (40000, 15)
#    id  song_duration_ms  acousticness  danceability    energy  \
# 0   0          212990.0      0.642286      0.856520  0.707073
# 1   1               NaN      0.054866      0.733289  0.835545
# 2   2          193213.0           NaN      0.188387  0.783524
# 3   3          249893.0      0.488660      0.585234  0.552685
# 4   4          165969.0      0.493017           NaN  0.740982
#
#    instrumentalness   key  liveness  loudness  audio_mode  speechiness  \
# 0          0.002001  10.0       NaN -5.619088           0     0.082570
# 1          0.000996   8.0  0.436428 -5.236965           1     0.127358
# 2         -0.002694   5.0  0.170499 -4.951759           0     0.052282
# 3          0.000608   0.0  0.094805 -7.893694           0     0.035618
# 4          0.002033  10.0  0.094891 -2.684095           0     0.050746
#
#         tempo  time_signature  audio_valence  song_popularity
# 0  158.386236               4       0.734642                0
# 1  102.752988               3       0.711531                1
# 2  178.685791               3       0.425536                0
# 3  128.715630               3       0.453597                0
# 4  121.928157               4       0.741311                0

# %%
test = pd.read_csv('../input/song-popularity-prediction/test.csv')
X_test = test.drop(['id'], axis=1)

# %%
X = data.drop(['id', 'song_popularity'], axis=1)
y = data['song_popularity']

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# # Model

# %%
class NeuralDecisionTree(keras.Model):
    def __init__(self, depth, num_features, used_features_rate, num_classes):
        super(NeuralDecisionTree, self).__init__()
        self.depth = depth
        self.num_leaves = 2 ** depth
        self.num_classes = num_classes
        
        num_used_features = int(num_features * used_features_rate)
        one_hot = np.eye(num_features)
        sampled_feature_indicies = np.random.choice(
            np.arange(num_features), num_used_features, replace=False
        )
        self.used_features_mask = one_hot[sampled_feature_indicies]

        self.pi = tf.Variable(
            initial_value=tf.random_normal_initializer()(
                shape=[self.num_leaves, self.num_classes]
            ),
            dtype="float32",
            trainable=True,
        )
        
        self.decision_fn = L.Dense(
            units=self.num_leaves, activation="sigmoid", name="decision"
        )

    def call(self, features):
        batch_size = tf.shape(features)[0]
        
        features = tf.matmul(
            features, self.used_features_mask, transpose_b=True
        )  
        decisions = tf.expand_dims(
            self.decision_fn(features), axis=2
        )  
        decisions = L.concatenate(
            [decisions, 1 - decisions], axis=2
        ) 

        mu = tf.ones([batch_size, 1, 1])

        begin_idx = 1
        end_idx = 2
        
        for level in range(self.depth):
            mu = tf.reshape(mu, [batch_size, -1, 1]) 
            mu = tf.tile(mu, (1, 1, 2))
            level_decisions = decisions[
                :, begin_idx:end_idx, :
            ]
            mu = mu * level_decisions
            begin_idx = end_idx
            end_idx = begin_idx + 2 ** (level + 1)

        mu = tf.reshape(mu, [batch_size, self.num_leaves])
        probabilities = keras.activations.softmax(self.pi)
        outputs = tf.matmul(mu, probabilities)
        return outputs
    
class NeuralDecisionForest(keras.Model):
    def __init__(self, num_trees, depth, num_features, used_features_rate, num_classes):
        super(NeuralDecisionForest, self).__init__()
        self.ensemble = []
        self.num_classes = num_classes
        for _ in range(num_trees):
            self.ensemble.append(
                NeuralDecisionTree(depth, num_features, used_features_rate, num_classes)
            )

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        outputs = tf.zeros([batch_size, self.num_classes])

        for tree in self.ensemble:
            outputs += tree(inputs)
        outputs /= len(self.ensemble)
        return outputs

# %%
get_cat_pipeline = lambda: Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')), 
    ('encoder', OneHotEncoder(sparse=False))
])

get_num_pipeline = lambda: Pipeline([
    ('imputer', SimpleImputer(strategy='median')), 
    ('scaler', StandardScaler())
])

# %%
class model_config:
    NUMERIC_FEATURE_NAMES=[
        'song_duration_ms', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness',
        'speechiness', 'tempo', 'audio_valence'
    ]
    CATEGORICAL_FEATURE_NAMES=[
        'key','audio_mode','time_signature'   
    ]

MAX_EPOCHS  = 250

get_callbacks = lambda : [
    keras.callbacks.EarlyStopping(min_delta=1e-4, patience=10, verbose=1, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(patience=3, verbose=1)
]

# %% [markdown]
# # Training

# %%
preds_tree = []
preds_forest = []

for fold, (train_index, valid_index) in enumerate(skf.split(X, y)):
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

    num_pipeline = get_num_pipeline().fit(X_train[model_config.NUMERIC_FEATURE_NAMES])
    cat_pipeline = get_cat_pipeline().fit(X_train[model_config.CATEGORICAL_FEATURE_NAMES])
    
    X_train = np.hstack((
        num_pipeline.transform(X_train[model_config.NUMERIC_FEATURE_NAMES]),
        cat_pipeline.transform(X_train[model_config.CATEGORICAL_FEATURE_NAMES])
    ))
    X_valid = np.hstack((
        num_pipeline.transform(X_valid[model_config.NUMERIC_FEATURE_NAMES]),
        cat_pipeline.transform(X_valid[model_config.CATEGORICAL_FEATURE_NAMES])
    ))
    X_test_ = np.hstack((
        num_pipeline.transform(X_test[model_config.NUMERIC_FEATURE_NAMES]),
        cat_pipeline.transform(X_test[model_config.CATEGORICAL_FEATURE_NAMES])
    ))
    
    neural_decsion_tree = NeuralDecisionTree(
        depth=5, num_features=X_train.shape[1], used_features_rate=1.0, num_classes=2
    )
    neural_decsion_tree.compile(
        loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy']
    )
    neural_decsion_tree.fit(
        X_train, y_train, validation_data=(X_valid, y_valid), callbacks=get_callbacks(), 
        epochs=MAX_EPOCHS
    )  
    preds_tree.append(neural_decsion_tree.predict(X_test_))
    
    neural_decsion_forest = NeuralDecisionForest(
        num_trees=10, depth=5, num_features=X_train.shape[1], used_features_rate=0.8, num_classes=2
    )
    neural_decsion_forest.compile(
        loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy']
    )
    neural_decsion_forest.fit(
        X_train, y_train, validation_data=(X_valid, y_valid), callbacks=get_callbacks(), 
        epochs=MAX_EPOCHS
    )  
    preds_forest.append(neural_decsion_forest.predict(X_test_))
# Out:
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2022-01-20 07:03:23.498066: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-01-20 07:03:23.630186: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/250
# 1000/1000 [==============================] - 3s 2ms/step - loss: 0.6592 - accuracy: 0.6356 - val_loss: 0.6527 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6528 - accuracy: 0.6356 - val_loss: 0.6515 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6517 - accuracy: 0.6356 - val_loss: 0.6510 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6509 - accuracy: 0.6356 - val_loss: 0.6510 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6504 - accuracy: 0.6356 - val_loss: 0.6510 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6498 - accuracy: 0.6357 - val_loss: 0.6510 - val_accuracy: 0.6357
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 7/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6493 - accuracy: 0.6357 - val_loss: 0.6509 - val_accuracy: 0.6357
# Epoch 8/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6492 - accuracy: 0.6357 - val_loss: 0.6509 - val_accuracy: 0.6359
# Epoch 9/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6491 - accuracy: 0.6357 - val_loss: 0.6509 - val_accuracy: 0.6359
# Epoch 10/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6491 - accuracy: 0.6357 - val_loss: 0.6509 - val_accuracy: 0.6359
# Epoch 11/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6490 - accuracy: 0.6358 - val_loss: 0.6509 - val_accuracy: 0.6359
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 12/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6489 - accuracy: 0.6358 - val_loss: 0.6509 - val_accuracy: 0.6359
# Epoch 13/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6489 - accuracy: 0.6358 - val_loss: 0.6509 - val_accuracy: 0.6359
# Epoch 14/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6489 - accuracy: 0.6358 - val_loss: 0.6509 - val_accuracy: 0.6359
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 15/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6489 - accuracy: 0.6358 - val_loss: 0.6509 - val_accuracy: 0.6359
# Epoch 16/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6489 - accuracy: 0.6358 - val_loss: 0.6509 - val_accuracy: 0.6359
# Epoch 17/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6489 - accuracy: 0.6358 - val_loss: 0.6509 - val_accuracy: 0.6359
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 18/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6489 - accuracy: 0.6358 - val_loss: 0.6509 - val_accuracy: 0.6359
# Restoring model weights from the end of the best epoch.
# Epoch 00018: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 12s 7ms/step - loss: 0.6607 - accuracy: 0.6354 - val_loss: 0.6531 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6528 - accuracy: 0.6356 - val_loss: 0.6517 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6517 - accuracy: 0.6356 - val_loss: 0.6511 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6509 - accuracy: 0.6356 - val_loss: 0.6510 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6503 - accuracy: 0.6356 - val_loss: 0.6507 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6497 - accuracy: 0.6356 - val_loss: 0.6508 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6492 - accuracy: 0.6355 - val_loss: 0.6506 - val_accuracy: 0.6359
# Epoch 8/250
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.6487 - accuracy: 0.6357 - val_loss: 0.6503 - val_accuracy: 0.6361
# Epoch 9/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6483 - accuracy: 0.6357 - val_loss: 0.6502 - val_accuracy: 0.6371
# Epoch 10/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6478 - accuracy: 0.6358 - val_loss: 0.6503 - val_accuracy: 0.6364
# Epoch 11/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6474 - accuracy: 0.6354 - val_loss: 0.6499 - val_accuracy: 0.6370
# Epoch 12/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6469 - accuracy: 0.6361 - val_loss: 0.6502 - val_accuracy: 0.6364
# Epoch 13/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6465 - accuracy: 0.6360 - val_loss: 0.6500 - val_accuracy: 0.6367
# Epoch 14/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6460 - accuracy: 0.6362 - val_loss: 0.6500 - val_accuracy: 0.6367
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 15/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6453 - accuracy: 0.6368 - val_loss: 0.6500 - val_accuracy: 0.6367
# Epoch 16/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6453 - accuracy: 0.6367 - val_loss: 0.6500 - val_accuracy: 0.6369
# Epoch 17/250
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.6452 - accuracy: 0.6366 - val_loss: 0.6500 - val_accuracy: 0.6369
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 18/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6451 - accuracy: 0.6367 - val_loss: 0.6500 - val_accuracy: 0.6369
# Epoch 19/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6451 - accuracy: 0.6367 - val_loss: 0.6500 - val_accuracy: 0.6369
# Epoch 20/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6451 - accuracy: 0.6367 - val_loss: 0.6500 - val_accuracy: 0.6369
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 21/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6451 - accuracy: 0.6367 - val_loss: 0.6500 - val_accuracy: 0.6369
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 3s 2ms/step - loss: 0.6597 - accuracy: 0.6357 - val_loss: 0.6528 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6527 - accuracy: 0.6356 - val_loss: 0.6512 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6516 - accuracy: 0.6356 - val_loss: 0.6504 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6510 - accuracy: 0.6356 - val_loss: 0.6500 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6505 - accuracy: 0.6355 - val_loss: 0.6497 - val_accuracy: 0.6359
# Epoch 6/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6500 - accuracy: 0.6354 - val_loss: 0.6496 - val_accuracy: 0.6357
# Epoch 7/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6496 - accuracy: 0.6359 - val_loss: 0.6495 - val_accuracy: 0.6357
# Epoch 8/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6492 - accuracy: 0.6362 - val_loss: 0.6496 - val_accuracy: 0.6357
# Epoch 9/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6488 - accuracy: 0.6359 - val_loss: 0.6496 - val_accuracy: 0.6360
# Epoch 10/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6484 - accuracy: 0.6361 - val_loss: 0.6495 - val_accuracy: 0.6352
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6478 - accuracy: 0.6367 - val_loss: 0.6495 - val_accuracy: 0.6352
# Epoch 12/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6477 - accuracy: 0.6365 - val_loss: 0.6495 - val_accuracy: 0.6352
# Epoch 13/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6477 - accuracy: 0.6367 - val_loss: 0.6495 - val_accuracy: 0.6354
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 14/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6476 - accuracy: 0.6367 - val_loss: 0.6495 - val_accuracy: 0.6354
# Epoch 15/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6476 - accuracy: 0.6368 - val_loss: 0.6495 - val_accuracy: 0.6354
# Epoch 16/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6476 - accuracy: 0.6367 - val_loss: 0.6495 - val_accuracy: 0.6354
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 17/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6476 - accuracy: 0.6367 - val_loss: 0.6495 - val_accuracy: 0.6355
# Restoring model weights from the end of the best epoch.
# Epoch 00017: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 11s 7ms/step - loss: 0.6599 - accuracy: 0.6356 - val_loss: 0.6531 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6530 - accuracy: 0.6356 - val_loss: 0.6514 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6518 - accuracy: 0.6356 - val_loss: 0.6503 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6510 - accuracy: 0.6356 - val_loss: 0.6498 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6503 - accuracy: 0.6356 - val_loss: 0.6495 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6497 - accuracy: 0.6355 - val_loss: 0.6495 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6493 - accuracy: 0.6356 - val_loss: 0.6493 - val_accuracy: 0.6357
# Epoch 8/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6488 - accuracy: 0.6357 - val_loss: 0.6492 - val_accuracy: 0.6354
# Epoch 9/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6483 - accuracy: 0.6357 - val_loss: 0.6491 - val_accuracy: 0.6357
# Epoch 10/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6479 - accuracy: 0.6359 - val_loss: 0.6491 - val_accuracy: 0.6360
# Epoch 11/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6475 - accuracy: 0.6357 - val_loss: 0.6491 - val_accuracy: 0.6363
# Epoch 12/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6471 - accuracy: 0.6362 - val_loss: 0.6492 - val_accuracy: 0.6361
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6464 - accuracy: 0.6362 - val_loss: 0.6492 - val_accuracy: 0.6359
# Epoch 14/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6464 - accuracy: 0.6362 - val_loss: 0.6492 - val_accuracy: 0.6357
# Epoch 15/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6463 - accuracy: 0.6363 - val_loss: 0.6492 - val_accuracy: 0.6360
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 16/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6462 - accuracy: 0.6363 - val_loss: 0.6492 - val_accuracy: 0.6360
# Epoch 17/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6462 - accuracy: 0.6363 - val_loss: 0.6492 - val_accuracy: 0.6360
# Epoch 18/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6462 - accuracy: 0.6363 - val_loss: 0.6492 - val_accuracy: 0.6360
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 19/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6462 - accuracy: 0.6363 - val_loss: 0.6492 - val_accuracy: 0.6360
# Restoring model weights from the end of the best epoch.
# Epoch 00019: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 3s 2ms/step - loss: 0.6596 - accuracy: 0.6346 - val_loss: 0.6537 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6526 - accuracy: 0.6356 - val_loss: 0.6529 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6517 - accuracy: 0.6356 - val_loss: 0.6524 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6511 - accuracy: 0.6356 - val_loss: 0.6519 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6506 - accuracy: 0.6357 - val_loss: 0.6516 - val_accuracy: 0.6348
# Epoch 6/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6502 - accuracy: 0.6355 - val_loss: 0.6514 - val_accuracy: 0.6346
# Epoch 7/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6498 - accuracy: 0.6354 - val_loss: 0.6510 - val_accuracy: 0.6351
# Epoch 8/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6495 - accuracy: 0.6357 - val_loss: 0.6508 - val_accuracy: 0.6354
# Epoch 9/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6491 - accuracy: 0.6363 - val_loss: 0.6505 - val_accuracy: 0.6361
# Epoch 10/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6488 - accuracy: 0.6362 - val_loss: 0.6504 - val_accuracy: 0.6354
# Epoch 11/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6484 - accuracy: 0.6363 - val_loss: 0.6503 - val_accuracy: 0.6364
# Epoch 12/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6480 - accuracy: 0.6367 - val_loss: 0.6501 - val_accuracy: 0.6364
# Epoch 13/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6477 - accuracy: 0.6366 - val_loss: 0.6501 - val_accuracy: 0.6374
# Epoch 14/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6473 - accuracy: 0.6366 - val_loss: 0.6500 - val_accuracy: 0.6373
# Epoch 15/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6470 - accuracy: 0.6363 - val_loss: 0.6501 - val_accuracy: 0.6370
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6462 - accuracy: 0.6367 - val_loss: 0.6501 - val_accuracy: 0.6370
# Epoch 17/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6462 - accuracy: 0.6367 - val_loss: 0.6501 - val_accuracy: 0.6371
# Epoch 18/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6461 - accuracy: 0.6367 - val_loss: 0.6501 - val_accuracy: 0.6374
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 19/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6460 - accuracy: 0.6369 - val_loss: 0.6501 - val_accuracy: 0.6373
# Epoch 20/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6460 - accuracy: 0.6368 - val_loss: 0.6501 - val_accuracy: 0.6375
# Epoch 21/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6460 - accuracy: 0.6368 - val_loss: 0.6501 - val_accuracy: 0.6374
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 22/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6460 - accuracy: 0.6369 - val_loss: 0.6501 - val_accuracy: 0.6374
# Restoring model weights from the end of the best epoch.
# Epoch 00022: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 11s 7ms/step - loss: 0.6590 - accuracy: 0.6355 - val_loss: 0.6535 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6525 - accuracy: 0.6356 - val_loss: 0.6526 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6516 - accuracy: 0.6356 - val_loss: 0.6522 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6509 - accuracy: 0.6356 - val_loss: 0.6518 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6504 - accuracy: 0.6356 - val_loss: 0.6515 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6499 - accuracy: 0.6356 - val_loss: 0.6512 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6494 - accuracy: 0.6356 - val_loss: 0.6508 - val_accuracy: 0.6356
# Epoch 8/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6489 - accuracy: 0.6356 - val_loss: 0.6507 - val_accuracy: 0.6356
# Epoch 9/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6485 - accuracy: 0.6359 - val_loss: 0.6505 - val_accuracy: 0.6361
# Epoch 10/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6480 - accuracy: 0.6364 - val_loss: 0.6504 - val_accuracy: 0.6361
# Epoch 11/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6476 - accuracy: 0.6360 - val_loss: 0.6502 - val_accuracy: 0.6355
# Epoch 12/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6471 - accuracy: 0.6357 - val_loss: 0.6500 - val_accuracy: 0.6356
# Epoch 13/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6467 - accuracy: 0.6365 - val_loss: 0.6502 - val_accuracy: 0.6356
# Epoch 14/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6463 - accuracy: 0.6360 - val_loss: 0.6500 - val_accuracy: 0.6363
# Epoch 15/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6457 - accuracy: 0.6361 - val_loss: 0.6500 - val_accuracy: 0.6389
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6451 - accuracy: 0.6365 - val_loss: 0.6500 - val_accuracy: 0.6382
# Epoch 17/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6450 - accuracy: 0.6366 - val_loss: 0.6500 - val_accuracy: 0.6380
# Epoch 18/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6449 - accuracy: 0.6366 - val_loss: 0.6500 - val_accuracy: 0.6380
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 19/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6449 - accuracy: 0.6365 - val_loss: 0.6500 - val_accuracy: 0.6380
# Epoch 20/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6449 - accuracy: 0.6365 - val_loss: 0.6500 - val_accuracy: 0.6379
# Epoch 21/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6449 - accuracy: 0.6365 - val_loss: 0.6500 - val_accuracy: 0.6379
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 22/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6448 - accuracy: 0.6364 - val_loss: 0.6500 - val_accuracy: 0.6379
# Restoring model weights from the end of the best epoch.
# Epoch 00022: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6594 - accuracy: 0.6345 - val_loss: 0.6537 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6526 - accuracy: 0.6356 - val_loss: 0.6531 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6517 - accuracy: 0.6356 - val_loss: 0.6528 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6511 - accuracy: 0.6356 - val_loss: 0.6526 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6505 - accuracy: 0.6356 - val_loss: 0.6526 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6499 - accuracy: 0.6356 - val_loss: 0.6523 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6491 - accuracy: 0.6356 - val_loss: 0.6523 - val_accuracy: 0.6356
# Epoch 8/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6487 - accuracy: 0.6357 - val_loss: 0.6523 - val_accuracy: 0.6355
# Epoch 9/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6482 - accuracy: 0.6357 - val_loss: 0.6523 - val_accuracy: 0.6352
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6474 - accuracy: 0.6358 - val_loss: 0.6523 - val_accuracy: 0.6350
# Epoch 11/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6474 - accuracy: 0.6358 - val_loss: 0.6523 - val_accuracy: 0.6350
# Epoch 12/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6473 - accuracy: 0.6358 - val_loss: 0.6524 - val_accuracy: 0.6349
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 13/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6473 - accuracy: 0.6357 - val_loss: 0.6524 - val_accuracy: 0.6349
# Epoch 14/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6473 - accuracy: 0.6357 - val_loss: 0.6524 - val_accuracy: 0.6349
# Epoch 15/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6472 - accuracy: 0.6357 - val_loss: 0.6524 - val_accuracy: 0.6349
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 16/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6472 - accuracy: 0.6358 - val_loss: 0.6524 - val_accuracy: 0.6349
# Restoring model weights from the end of the best epoch.
# Epoch 00016: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 12s 7ms/step - loss: 0.6606 - accuracy: 0.6345 - val_loss: 0.6535 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6525 - accuracy: 0.6356 - val_loss: 0.6527 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6515 - accuracy: 0.6356 - val_loss: 0.6524 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6508 - accuracy: 0.6356 - val_loss: 0.6521 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6502 - accuracy: 0.6356 - val_loss: 0.6519 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6495 - accuracy: 0.6356 - val_loss: 0.6518 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6490 - accuracy: 0.6356 - val_loss: 0.6518 - val_accuracy: 0.6359
# Epoch 8/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6484 - accuracy: 0.6356 - val_loss: 0.6521 - val_accuracy: 0.6356
# Epoch 9/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6480 - accuracy: 0.6357 - val_loss: 0.6517 - val_accuracy: 0.6357
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6473 - accuracy: 0.6358 - val_loss: 0.6517 - val_accuracy: 0.6356
# Epoch 11/250
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.6473 - accuracy: 0.6358 - val_loss: 0.6517 - val_accuracy: 0.6356
# Epoch 12/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6472 - accuracy: 0.6360 - val_loss: 0.6517 - val_accuracy: 0.6356
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 13/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6471 - accuracy: 0.6359 - val_loss: 0.6517 - val_accuracy: 0.6355
# Epoch 14/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6471 - accuracy: 0.6359 - val_loss: 0.6517 - val_accuracy: 0.6355
# Epoch 15/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6471 - accuracy: 0.6358 - val_loss: 0.6517 - val_accuracy: 0.6355
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 16/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6471 - accuracy: 0.6359 - val_loss: 0.6517 - val_accuracy: 0.6355
# Restoring model weights from the end of the best epoch.
# Epoch 00016: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6594 - accuracy: 0.6311 - val_loss: 0.6544 - val_accuracy: 0.6355
# Epoch 2/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6521 - accuracy: 0.6356 - val_loss: 0.6535 - val_accuracy: 0.6355
# Epoch 3/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6509 - accuracy: 0.6356 - val_loss: 0.6532 - val_accuracy: 0.6355
# Epoch 4/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6501 - accuracy: 0.6356 - val_loss: 0.6529 - val_accuracy: 0.6355
# Epoch 5/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6496 - accuracy: 0.6355 - val_loss: 0.6528 - val_accuracy: 0.6355
# Epoch 6/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6492 - accuracy: 0.6356 - val_loss: 0.6528 - val_accuracy: 0.6352
# Epoch 7/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6488 - accuracy: 0.6360 - val_loss: 0.6527 - val_accuracy: 0.6354
# Epoch 8/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6484 - accuracy: 0.6359 - val_loss: 0.6525 - val_accuracy: 0.6352
# Epoch 9/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6481 - accuracy: 0.6363 - val_loss: 0.6526 - val_accuracy: 0.6350
# Epoch 10/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6476 - accuracy: 0.6355 - val_loss: 0.6526 - val_accuracy: 0.6350
# Epoch 11/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6473 - accuracy: 0.6357 - val_loss: 0.6529 - val_accuracy: 0.6340
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6466 - accuracy: 0.6361 - val_loss: 0.6528 - val_accuracy: 0.6340
# Epoch 13/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6465 - accuracy: 0.6361 - val_loss: 0.6528 - val_accuracy: 0.6338
# Epoch 14/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6465 - accuracy: 0.6361 - val_loss: 0.6528 - val_accuracy: 0.6336
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 15/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6464 - accuracy: 0.6362 - val_loss: 0.6528 - val_accuracy: 0.6338
# Epoch 16/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6464 - accuracy: 0.6362 - val_loss: 0.6528 - val_accuracy: 0.6339
# Epoch 17/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6464 - accuracy: 0.6361 - val_loss: 0.6528 - val_accuracy: 0.6339
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 18/250
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6464 - accuracy: 0.6360 - val_loss: 0.6528 - val_accuracy: 0.6339
# Restoring model weights from the end of the best epoch.
# Epoch 00018: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 11s 7ms/step - loss: 0.6596 - accuracy: 0.6355 - val_loss: 0.6546 - val_accuracy: 0.6355
# Epoch 2/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6525 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6355
# Epoch 3/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6513 - accuracy: 0.6356 - val_loss: 0.6534 - val_accuracy: 0.6355
# Epoch 4/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6506 - accuracy: 0.6356 - val_loss: 0.6531 - val_accuracy: 0.6355
# Epoch 5/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6500 - accuracy: 0.6356 - val_loss: 0.6527 - val_accuracy: 0.6354
# Epoch 6/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6494 - accuracy: 0.6357 - val_loss: 0.6527 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6488 - accuracy: 0.6355 - val_loss: 0.6526 - val_accuracy: 0.6352
# Epoch 8/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6483 - accuracy: 0.6354 - val_loss: 0.6524 - val_accuracy: 0.6355
# Epoch 9/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6478 - accuracy: 0.6358 - val_loss: 0.6523 - val_accuracy: 0.6363
# Epoch 10/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6474 - accuracy: 0.6360 - val_loss: 0.6521 - val_accuracy: 0.6364
# Epoch 11/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6469 - accuracy: 0.6359 - val_loss: 0.6523 - val_accuracy: 0.6360
# Epoch 12/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6465 - accuracy: 0.6363 - val_loss: 0.6522 - val_accuracy: 0.6363
# Epoch 13/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6461 - accuracy: 0.6367 - val_loss: 0.6520 - val_accuracy: 0.6361
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6454 - accuracy: 0.6362 - val_loss: 0.6520 - val_accuracy: 0.6359
# Epoch 15/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6453 - accuracy: 0.6363 - val_loss: 0.6521 - val_accuracy: 0.6357
# Epoch 16/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6453 - accuracy: 0.6365 - val_loss: 0.6521 - val_accuracy: 0.6355
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 17/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6452 - accuracy: 0.6363 - val_loss: 0.6521 - val_accuracy: 0.6357
# Epoch 18/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6452 - accuracy: 0.6364 - val_loss: 0.6521 - val_accuracy: 0.6356
# Epoch 19/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6452 - accuracy: 0.6364 - val_loss: 0.6521 - val_accuracy: 0.6356
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 20/250
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6452 - accuracy: 0.6364 - val_loss: 0.6521 - val_accuracy: 0.6356
# Restoring model weights from the end of the best epoch.
# Epoch 00020: early stopping

# %% [markdown]
# # Submissions

# %%
submissions = pd.read_csv('../input/song-popularity-prediction/sample_submission.csv')
submissions['song_popularity'] = np.array([arr[:, 1] for arr in preds_tree]).mean(axis=0)
submissions.to_csv('preds_tree.csv', index=False)

submissions['song_popularity'] = np.array([arr[:, 1] for arr in preds_forest]).mean(axis=0)
submissions.to_csv('preds_forest.csv', index=False)
