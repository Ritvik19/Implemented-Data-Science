# %% [markdown]
# # Deep Neural Decision Forests
#
# Even though deep learning has attained trendendous success on data domains such as images, audio and texts.
# GDBT still rule the domain of tabular data.
#
# In this note we will discuss [Deep Neural Decision Forests](https://ieeexplore.ieee.org/document/7410529) for tabular deep learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers as L

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
import joblib

# %% [markdown]
# # Data

# %%
data = pd.read_csv('../input/song-popularity-prediction/train.csv')
print(data.shape)
data.head()
# Out:
# (40000, 15)
#    id  song_duration_ms  acousticness  danceability    energy  \
# 0   0          212990.0      0.642286      0.856520  0.707073
# 1   1               NaN      0.054866      0.733289  0.835545
# 2   2          193213.0           NaN      0.188387  0.783524
# 3   3          249893.0      0.488660      0.585234  0.552685
# 4   4          165969.0      0.493017           NaN  0.740982
#
#    instrumentalness   key  liveness  loudness  audio_mode  speechiness  \
# 0          0.002001  10.0       NaN -5.619088           0     0.082570
# 1          0.000996   8.0  0.436428 -5.236965           1     0.127358
# 2         -0.002694   5.0  0.170499 -4.951759           0     0.052282
# 3          0.000608   0.0  0.094805 -7.893694           0     0.035618
# 4          0.002033  10.0  0.094891 -2.684095           0     0.050746
#
#         tempo  time_signature  audio_valence  song_popularity
# 0  158.386236               4       0.734642                0
# 1  102.752988               3       0.711531                1
# 2  178.685791               3       0.425536                0
# 3  128.715630               3       0.453597                0
# 4  121.928157               4       0.741311                0

# %%
test = pd.read_csv('../input/song-popularity-prediction/test.csv')
X_test = test.drop(['id'], axis=1)

# %%
X = data.drop(['id', 'song_popularity'], axis=1)
y = data['song_popularity']

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# # Model

# %%
class NeuralDecisionTree(keras.Model):
    def __init__(self, depth, num_features, used_features_rate, num_classes):
        super(NeuralDecisionTree, self).__init__()
        self.depth = depth
        self.num_leaves = 2 ** depth
        self.num_classes = num_classes
        
        num_used_features = int(num_features * used_features_rate)
        one_hot = np.eye(num_features)
        sampled_feature_indicies = np.random.choice(
            np.arange(num_features), num_used_features, replace=False
        )
        self.used_features_mask = one_hot[sampled_feature_indicies]

        self.pi = tf.Variable(
            initial_value=tf.random_normal_initializer()(
                shape=[self.num_leaves, self.num_classes]
            ),
            dtype="float32",
            trainable=True,
        )
        
        self.decision_fn = L.Dense(
            units=self.num_leaves, activation="sigmoid", name="decision"
        )

    def call(self, features):
        batch_size = tf.shape(features)[0]
        
        features = tf.matmul(
            features, self.used_features_mask, transpose_b=True
        )  
        decisions = tf.expand_dims(
            self.decision_fn(features), axis=2
        )  
        decisions = L.concatenate(
            [decisions, 1 - decisions], axis=2
        ) 

        mu = tf.ones([batch_size, 1, 1])

        begin_idx = 1
        end_idx = 2
        
        for level in range(self.depth):
            mu = tf.reshape(mu, [batch_size, -1, 1]) 
            mu = tf.tile(mu, (1, 1, 2))
            level_decisions = decisions[
                :, begin_idx:end_idx, :
            ]
            mu = mu * level_decisions
            begin_idx = end_idx
            end_idx = begin_idx + 2 ** (level + 1)

        mu = tf.reshape(mu, [batch_size, self.num_leaves])
        probabilities = keras.activations.softmax(self.pi)
        outputs = tf.matmul(mu, probabilities)
        return outputs
    
class NeuralDecisionForest(keras.Model):
    def __init__(self, num_trees, depth, num_features, used_features_rate, num_classes):
        super(NeuralDecisionForest, self).__init__()
        self.ensemble = []
        self.num_classes = num_classes
        for _ in range(num_trees):
            self.ensemble.append(
                NeuralDecisionTree(depth, num_features, used_features_rate, num_classes)
            )

    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        outputs = tf.zeros([batch_size, self.num_classes])

        for tree in self.ensemble:
            outputs += tree(inputs)
        outputs /= len(self.ensemble)
        return outputs

# %%
class model_config:
    NUMERIC_FEATURE_NAMES=[
        'song_duration_ms', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness',
        'speechiness', 'tempo', 'audio_valence'
    ]
    CATEGORICAL_FEATURE_NAMES=[
        'key','audio_mode','time_signature'   
    ]

MAX_EPOCHS  = 250

get_callbacks = lambda : [
    keras.callbacks.EarlyStopping(min_delta=1e-4, patience=10, verbose=1, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(patience=3, verbose=1)
]

# %% [markdown]
# # Training

# %%
preds_tree = []
preds_forest = []

for fold, (train_index, valid_index) in enumerate(skf.split(X, y)):
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

    mean_imputer = SimpleImputer(strategy='median').fit(X_train[model_config.NUMERIC_FEATURE_NAMES])
    mode_imputer = SimpleImputer(strategy='most_frequent').fit(X_train[model_config.CATEGORICAL_FEATURE_NAMES])
    
    X_train = np.hstack((
        mean_imputer.transform(X_train[model_config.NUMERIC_FEATURE_NAMES]),
        mode_imputer.transform(X_train[model_config.CATEGORICAL_FEATURE_NAMES])
    ))
    X_valid = np.hstack((
        mean_imputer.transform(X_valid[model_config.NUMERIC_FEATURE_NAMES]),
        mode_imputer.transform(X_valid[model_config.CATEGORICAL_FEATURE_NAMES])
    ))
    X_test_ = np.hstack((
        mean_imputer.transform(X_test[model_config.NUMERIC_FEATURE_NAMES]),
        mode_imputer.transform(X_test[model_config.CATEGORICAL_FEATURE_NAMES])
    ))
    
    neural_decsion_tree = NeuralDecisionTree(depth=10, num_features=X.shape[1], used_features_rate=0.8, num_classes=2)
    neural_decsion_tree.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy'])
    neural_decsion_tree.fit(
        X_train, y_train, validation_data=(X_valid, y_valid), callbacks=get_callbacks(), epochs=MAX_EPOCHS
    )  
    preds_tree.append(neural_decsion_tree.predict(X_test_))
    
    neural_decsion_forest = NeuralDecisionForest(
        num_trees=10, depth=10, num_features=X.shape[1], used_features_rate=0.8, num_classes=2
    )
    neural_decsion_forest.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy'])
    neural_decsion_forest.fit(
        X_train, y_train, validation_data=(X_valid, y_valid), callbacks=get_callbacks(), epochs=MAX_EPOCHS
    )  
    preds_forest.append(neural_decsion_forest.predict(X_test_))
# Out:
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2022-01-19 13:53:39.458353: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-01-19 13:53:39.603840: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/250
# 1000/1000 [==============================] - 9s 8ms/step - loss: 0.6615 - accuracy: 0.6278 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 8/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 9/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 10/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 11/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 58s 49ms/step - loss: 0.6600 - accuracy: 0.6332 - val_loss: 0.6558 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6557 - accuracy: 0.6356 - val_loss: 0.6550 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6554 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6552 - accuracy: 0.6356 - val_loss: 0.6550 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6553 - accuracy: 0.6356 - val_loss: 0.6545 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6551 - accuracy: 0.6356 - val_loss: 0.6550 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6551 - accuracy: 0.6356 - val_loss: 0.6545 - val_accuracy: 0.6356
# Epoch 8/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6543 - val_accuracy: 0.6356
# Epoch 9/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6545 - val_accuracy: 0.6356
# Epoch 10/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6543 - val_accuracy: 0.6356
# Epoch 11/250
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6543 - val_accuracy: 0.6356
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 13/250
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 14/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 15/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 16/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 17/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 18/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 19/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 20/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 21/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 22/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Restoring model weights from the end of the best epoch.
# Epoch 00022: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 9s 8ms/step - loss: 0.6595 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 8/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 9/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 10/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 11/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 57s 48ms/step - loss: 0.6608 - accuracy: 0.6335 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6558 - accuracy: 0.6356 - val_loss: 0.6553 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6555 - accuracy: 0.6356 - val_loss: 0.6548 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6554 - accuracy: 0.6356 - val_loss: 0.6548 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6553 - accuracy: 0.6356 - val_loss: 0.6543 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6552 - accuracy: 0.6356 - val_loss: 0.6544 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6553 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 8/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6546 - val_accuracy: 0.6356
# Epoch 9/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6551 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 10/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6551 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
# Epoch 12/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
# Epoch 13/250
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
# Epoch 14/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 15/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
# Epoch 16/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
# Epoch 17/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 18/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6548 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
# Epoch 19/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6548 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
# Epoch 20/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6548 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 21/250
# 1000/1000 [==============================] - 46s 47ms/step - loss: 0.6548 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 9s 8ms/step - loss: 0.6596 - accuracy: 0.6356 - val_loss: 0.6560 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/250
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 8/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 9/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Epoch 10/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 11/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6356
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 56s 48ms/step - loss: 0.6611 - accuracy: 0.6337 - val_loss: 0.6565 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6558 - accuracy: 0.6356 - val_loss: 0.6557 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6554 - accuracy: 0.6356 - val_loss: 0.6555 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 47s 46ms/step - loss: 0.6553 - accuracy: 0.6356 - val_loss: 0.6553 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6551 - accuracy: 0.6356 - val_loss: 0.6561 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6551 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6550 - val_accuracy: 0.6356
# Epoch 8/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6548 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6356
# Epoch 9/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6550 - val_accuracy: 0.6356
# Epoch 10/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6548 - val_accuracy: 0.6356
# Epoch 11/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6547 - val_accuracy: 0.6356
# Epoch 12/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6544 - accuracy: 0.6356 - val_loss: 0.6554 - val_accuracy: 0.6356
# Epoch 13/250
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6547 - val_accuracy: 0.6356
# Epoch 14/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6543 - accuracy: 0.6356 - val_loss: 0.6546 - val_accuracy: 0.6356
# Epoch 15/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6542 - accuracy: 0.6356 - val_loss: 0.6547 - val_accuracy: 0.6356
# Epoch 16/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6542 - accuracy: 0.6356 - val_loss: 0.6546 - val_accuracy: 0.6356
# Epoch 17/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6540 - accuracy: 0.6356 - val_loss: 0.6544 - val_accuracy: 0.6356
# Epoch 18/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6540 - accuracy: 0.6356 - val_loss: 0.6545 - val_accuracy: 0.6356
# Epoch 19/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6543 - val_accuracy: 0.6356
# Epoch 20/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6543 - val_accuracy: 0.6356
# Epoch 21/250
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.6538 - accuracy: 0.6356 - val_loss: 0.6544 - val_accuracy: 0.6356
# Epoch 22/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6537 - accuracy: 0.6356 - val_loss: 0.6542 - val_accuracy: 0.6356
# Epoch 23/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6536 - accuracy: 0.6356 - val_loss: 0.6542 - val_accuracy: 0.6356
# Epoch 24/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6536 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6356
# Epoch 25/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6535 - accuracy: 0.6356 - val_loss: 0.6542 - val_accuracy: 0.6356
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 26/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6533 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
# Epoch 27/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
# Epoch 28/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
# Epoch 29/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 30/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
# Epoch 31/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
# Epoch 32/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 33/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
# Epoch 34/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
# Epoch 35/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 36/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 12s 11ms/step - loss: 0.6580 - accuracy: 0.6356 - val_loss: 0.6558 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.6557 - accuracy: 0.6356 - val_loss: 0.6553 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6555 - accuracy: 0.6356 - val_loss: 0.6552 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6555 - accuracy: 0.6357 - val_loss: 0.6552 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6554 - accuracy: 0.6356 - val_loss: 0.6552 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6554 - accuracy: 0.6354 - val_loss: 0.6553 - val_accuracy: 0.6356
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 7/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6552 - accuracy: 0.6356 - val_loss: 0.6551 - val_accuracy: 0.6356
# Epoch 8/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6551 - accuracy: 0.6356 - val_loss: 0.6550 - val_accuracy: 0.6355
# Epoch 9/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6551 - accuracy: 0.6356 - val_loss: 0.6550 - val_accuracy: 0.6356
# Epoch 10/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6551 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6356
# Epoch 11/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6550 - accuracy: 0.6357 - val_loss: 0.6549 - val_accuracy: 0.6355
# Epoch 12/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6356
# Epoch 13/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6355
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 14/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6355
# Epoch 15/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6355
# Epoch 16/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6355
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 17/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6355
# Epoch 18/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6355
# Epoch 19/250
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6355
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 20/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6355
# Restoring model weights from the end of the best epoch.
# Epoch 00020: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 57s 48ms/step - loss: 0.6594 - accuracy: 0.6356 - val_loss: 0.6557 - val_accuracy: 0.6356
# Epoch 2/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6557 - accuracy: 0.6356 - val_loss: 0.6551 - val_accuracy: 0.6356
# Epoch 3/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6553 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6356
# Epoch 4/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6547 - val_accuracy: 0.6356
# Epoch 5/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6545 - val_accuracy: 0.6356
# Epoch 6/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6549 - accuracy: 0.6356 - val_loss: 0.6545 - val_accuracy: 0.6356
# Epoch 7/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6543 - val_accuracy: 0.6356
# Epoch 8/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6542 - val_accuracy: 0.6356
# Epoch 9/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 10/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6544 - accuracy: 0.6356 - val_loss: 0.6540 - val_accuracy: 0.6356
# Epoch 11/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6543 - accuracy: 0.6356 - val_loss: 0.6541 - val_accuracy: 0.6356
# Epoch 12/250
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6542 - accuracy: 0.6356 - val_loss: 0.6543 - val_accuracy: 0.6356
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6541 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
# Epoch 14/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6356
# Epoch 15/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6356
# Epoch 16/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6356
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 17/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6356
# Epoch 18/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6356
# Epoch 19/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6356
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 20/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6356
# Epoch 21/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6356
# Epoch 22/250
# 1000/1000 [==============================] - 48s 47ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6356
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 23/250
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.6538 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6356
# Restoring model weights from the end of the best epoch.
# Epoch 00023: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 9s 8ms/step - loss: 0.6583 - accuracy: 0.6312 - val_loss: 0.6557 - val_accuracy: 0.6355
# Epoch 2/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6553 - accuracy: 0.6356 - val_loss: 0.6558 - val_accuracy: 0.6355
# Epoch 3/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6551 - accuracy: 0.6356 - val_loss: 0.6558 - val_accuracy: 0.6355
# Epoch 4/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6557 - val_accuracy: 0.6355
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6548 - accuracy: 0.6356 - val_loss: 0.6557 - val_accuracy: 0.6355
# Epoch 6/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6548 - accuracy: 0.6356 - val_loss: 0.6557 - val_accuracy: 0.6355
# Epoch 7/250
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.6548 - accuracy: 0.6356 - val_loss: 0.6558 - val_accuracy: 0.6355
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 8/250
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6558 - val_accuracy: 0.6355
# Epoch 9/250
# 1000/1000 [==============================] - 9s 9ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6558 - val_accuracy: 0.6355
# Epoch 10/250
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6558 - val_accuracy: 0.6355
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 11/250
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6558 - val_accuracy: 0.6355
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Epoch 1/250
# 1000/1000 [==============================] - 57s 49ms/step - loss: 0.6598 - accuracy: 0.6354 - val_loss: 0.6558 - val_accuracy: 0.6355
# Epoch 2/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6554 - accuracy: 0.6356 - val_loss: 0.6558 - val_accuracy: 0.6355
# Epoch 3/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6552 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6355
# Epoch 4/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6548 - accuracy: 0.6356 - val_loss: 0.6567 - val_accuracy: 0.6355
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/250
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.6547 - accuracy: 0.6356 - val_loss: 0.6560 - val_accuracy: 0.6355
# Epoch 6/250
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6560 - val_accuracy: 0.6355
# Epoch 7/250
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6560 - val_accuracy: 0.6355
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 8/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6560 - val_accuracy: 0.6355
# Epoch 9/250
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6560 - val_accuracy: 0.6355
# Epoch 10/250
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6560 - val_accuracy: 0.6355
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 11/250
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6560 - val_accuracy: 0.6355
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping

# %% [markdown]
# # Submissions

# %%
submissions = pd.read_csv('../input/song-popularity-prediction/sample_submission.csv')
submissions['song_popularity'] = np.array([arr[:, 1] for arr in preds_tree]).mean(axis=0)
submissions.to_csv('preds_tree.csv', index=False)

submissions['song_popularity'] = np.array([arr[:, 1] for arr in preds_forest]).mean(axis=0)
submissions.to_csv('preds_forest.csv', index=False)
