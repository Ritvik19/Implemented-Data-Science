# %% [markdown]
# # Neural Oblivious Decision Ensembles
#
# Even though deep learning has attained trendendous success on data domains such as images, audio and texts.
# GDBT still rule the domain of tabular data.
#
# In this notebook we will discussa deep learning architecture [Neural Oblivious Decision Ensembles for Deep Learning on Tabular Data](https://arxiv.org/pdf/1909.06312.pdf) which is designed to work with any tabular data and generalizes ensembles of oblivious decision trees, but benefits from both end-to-end gradient-based optimization and the power of multi-layer hierarchical representation learning.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers as L
import tensorflow_addons as tfa
from tensorflow_probability import distributions, stats

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
import joblib

# %% [markdown]
# # Data

# %%
data = pd.read_csv('../input/song-popularity-prediction/train.csv')
print(data.shape)
data.head()
# Out:
# (40000, 15)
#    id  song_duration_ms  acousticness  danceability    energy  \
# 0   0          212990.0      0.642286      0.856520  0.707073
# 1   1               NaN      0.054866      0.733289  0.835545
# 2   2          193213.0           NaN      0.188387  0.783524
# 3   3          249893.0      0.488660      0.585234  0.552685
# 4   4          165969.0      0.493017           NaN  0.740982
#
#    instrumentalness   key  liveness  loudness  audio_mode  speechiness  \
# 0          0.002001  10.0       NaN -5.619088           0     0.082570
# 1          0.000996   8.0  0.436428 -5.236965           1     0.127358
# 2         -0.002694   5.0  0.170499 -4.951759           0     0.052282
# 3          0.000608   0.0  0.094805 -7.893694           0     0.035618
# 4          0.002033  10.0  0.094891 -2.684095           0     0.050746
#
#         tempo  time_signature  audio_valence  song_popularity
# 0  158.386236               4       0.734642                0
# 1  102.752988               3       0.711531                1
# 2  178.685791               3       0.425536                0
# 3  128.715630               3       0.453597                0
# 4  121.928157               4       0.741311                0

# %%
test = pd.read_csv('../input/song-popularity-prediction/test.csv')
X_test = test.drop(['id'], axis=1)

# %%
X = data.drop(['id', 'song_popularity'], axis=1)
y = data['song_popularity']

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)

# %% [markdown]
# # Model

# %%
@tf.function
def sparsemoid(inputs):
    return tf.clip_by_value(0.5 * inputs + 0.5, 0., 1.)


def get_binary_lookup_table(depth):
    # output: binary tensor [depth, 2**depth, 2]
    indices = tf.keras.backend.arange(0, 2**depth, 1)
    offsets = 2 ** tf.keras.backend.arange(0, depth, 1)
    bin_codes = (tf.reshape(indices, (1, -1)) // tf.reshape(offsets, (-1, 1)) % 2)
    bin_codes = tf.stack([bin_codes, 1 - bin_codes], axis=-1)
    bin_codes = tf.cast(bin_codes, 'float32')
    binary_lut = tf.Variable(initial_value=bin_codes, trainable=False)
    return binary_lut


def get_feature_selection_logits(n_trees, depth, dim):
    initializer = tf.keras.initializers.random_uniform()
    init_shape = (dim, n_trees, depth)
    init_value = initializer(shape=init_shape, dtype='float32')
    return tf.Variable(init_value, trainable=True)


def get_output_response(n_trees, depth, units):
    initializer = tf.keras.initializers.random_uniform()
    init_shape = (n_trees, units, 2**depth)
    init_value = initializer(init_shape, dtype='float32')
    return tf.Variable(initial_value=init_value, trainable=True)


def get_feature_thresholds(n_trees, depth):
    initializer = tf.ones_initializer()
    init_shape = (n_trees, depth)
    init_value = initializer(shape=init_shape, dtype='float32')
    return tf.Variable(init_value, trainable=True)


def get_log_temperatures(n_trees, depth):
    initializer = tf.ones_initializer()
    init_shape = (n_trees, depth)
    init_value = initializer(shape=init_shape, dtype='float32')
    return tf.Variable(initial_value=init_value, trainable=True)


def init_feature_thresholds(features, beta, n_trees, depth):
    sampler = distributions.Beta(beta, beta)
    percentiles_q = sampler.sample([n_trees * depth])

    flattened_feature_values = tf.map_fn(tf.keras.backend.flatten, features)
    percentile = stats.percentile(flattened_feature_values, 100*percentiles_q)
    feature_thresholds = tf.reshape(percentile, (n_trees, depth))
    return feature_thresholds


def init_log_temperatures(features, feature_thresholds):
    input_threshold_diff = tf.math.abs(features - feature_thresholds)
    log_temperatures = stats.percentile(input_threshold_diff, 50, axis=0)
    return log_temperatures

# %%
class ObliviousDecisionTree(L.Layer):
    def __init__(self,n_trees=3, depth=4, units=1,threshold_init_beta=1.):
        super().__init__()
        self.initialized = False
        self.n_trees = n_trees
        self.depth = depth
        self.units = units
        self.threshold_init_beta = threshold_init_beta

    def build(self, input_shape):
        dim = input_shape[-1]
        n_trees, depth, units = self.n_trees, self.depth, self.units
        self.feature_selection_logits = get_feature_selection_logits(n_trees, depth, dim)
        self.feature_thresholds = get_feature_thresholds(n_trees, depth)
        self.log_temperatures = get_log_temperatures(n_trees, depth)
        self.binary_lut = get_binary_lookup_table(depth)
        self.response = get_output_response(n_trees, depth, units)

    def _data_aware_initialization(self, inputs):
        beta, n_trees, depth = self.threshold_init_beta, self.n_trees, self.depth
        feature_values = self._get_feature_values(inputs)
        feature_thresholds = init_feature_thresholds(feature_values, beta, n_trees, depth)
        log_temperatures = init_log_temperatures(feature_values, feature_thresholds)
        self.feature_thresholds.assign(feature_thresholds)
        self.log_temperatures.assign(log_temperatures)

    def _get_feature_values(self, inputs, training=None):
        feature_selectors = tfa.activations.sparsemax(self.feature_selection_logits)
        feature_values = tf.einsum('bi,ind->bnd', inputs, feature_selectors)
        return feature_values

    def _get_feature_gates(self, feature_values):
        threshold_logits = (feature_values - self.feature_thresholds)
        threshold_logits = threshold_logits * tf.math.exp(-self.log_temperatures)
        threshold_logits = tf.stack([-threshold_logits, threshold_logits], axis=-1)
        feature_gates = sparsemoid(threshold_logits)
        return feature_gates

    def _get_aggregated_response(self, feature_gates):
        aggregated_gates = tf.einsum('bnds,dcs->bndc', feature_gates, self.binary_lut)
        aggregated_gates = tf.math.reduce_prod(aggregated_gates, axis=-2)
        aggregated_response = tf.einsum('bnc,nuc->bnu', aggregated_gates, self.response)
        return aggregated_response

    def call(self, inputs, training=None):
        if not self.initialized:
            self._data_aware_initialization(inputs)
            self.initialized = True

        feature_values = self._get_feature_values(inputs)
        feature_gates = self._get_feature_gates(feature_values)
        aggregated_response = self._get_aggregated_response(feature_gates)
        response_averaged_over_trees = tf.reduce_mean(aggregated_response, axis=1)
        return response_averaged_over_trees

# %%
class NODE(keras.Model):
    def __init__(self, units=1, n_layers=1, link=tf.identity, n_trees=3, tree_depth=4, threshold_init_beta=1):
        super().__init__()
        self.units = units
        self.n_layers = n_layers
        self.n_trees = n_trees
        self.tree_depth = tree_depth
        self.units = units
        self.threshold_init_beta = threshold_init_beta

        self.bn = L.BatchNormalization()
        self.ensemble = [ObliviousDecisionTree(
            n_trees=n_trees, depth=tree_depth, units=units,threshold_init_beta=threshold_init_beta
        ) for _ in range(n_layers)]
        self.link = link

    def call(self, inputs, training=None):
        x = self.bn(inputs, training=training)
        for tree in self.ensemble:
            h = tree(x)
            x = tf.concat([x, h], axis=1)
        return self.link(h)

# %%
get_cat_pipeline = lambda: Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')), 
    ('encoder', OneHotEncoder(sparse=False))
])

get_num_pipeline = lambda: Pipeline([
    ('imputer', SimpleImputer(strategy='median')), 
    ('scaler', StandardScaler())
])

# %%
class model_config:
    NUMERIC_FEATURE_NAMES=[
        'song_duration_ms', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness',
        'speechiness', 'tempo', 'audio_valence'
    ]
    CATEGORICAL_FEATURE_NAMES=[
        'key','audio_mode','time_signature'   
    ]

MAX_EPOCHS  = 250

get_callbacks = lambda : [
    keras.callbacks.EarlyStopping(min_delta=1e-4, patience=10, verbose=1, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(patience=3, verbose=1)
]

# %% [markdown]
# # Training

# %%
preds = []

for fold, (train_index, valid_index) in enumerate(skf.split(X, y)):
    X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

    num_pipeline = get_num_pipeline().fit(X_train[model_config.NUMERIC_FEATURE_NAMES])
    cat_pipeline = get_cat_pipeline().fit(X_train[model_config.CATEGORICAL_FEATURE_NAMES])
    
    X_train = np.hstack((
        num_pipeline.transform(X_train[model_config.NUMERIC_FEATURE_NAMES]),
        cat_pipeline.transform(X_train[model_config.CATEGORICAL_FEATURE_NAMES])
    ))
    X_valid = np.hstack((
        num_pipeline.transform(X_valid[model_config.NUMERIC_FEATURE_NAMES]),
        cat_pipeline.transform(X_valid[model_config.CATEGORICAL_FEATURE_NAMES])
    ))
    X_test_ = np.hstack((
        num_pipeline.transform(X_test[model_config.NUMERIC_FEATURE_NAMES]),
        cat_pipeline.transform(X_test[model_config.CATEGORICAL_FEATURE_NAMES])
    ))
    
    model = NODE()
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])
    model.fit(
        X_train, y_train, validation_data=(X_valid, y_valid), callbacks=get_callbacks(), 
        epochs=MAX_EPOCHS
    )  
    preds.append(model.predict(X_test_))
# Out:
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2022-01-22 07:11:54.352185: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-01-22 07:11:54.716634: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/250
# 1125/1125 [==============================] - 7s 4ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
# Epoch 2/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
# Epoch 3/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
# Epoch 4/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
# Epoch 6/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
# Epoch 7/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 8/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
# Epoch 9/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
# Epoch 10/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 11/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6211 - accuracy: 0.6356 - val_loss: 5.6185 - val_accuracy: 0.6357
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Epoch 1/250
# 1125/1125 [==============================] - 5s 4ms/step - loss: 0.7521 - accuracy: 0.6356 - val_loss: 0.6570 - val_accuracy: 0.6357
# Epoch 2/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6562 - accuracy: 0.6356 - val_loss: 0.6562 - val_accuracy: 0.6357
# Epoch 3/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6561 - accuracy: 0.6356 - val_loss: 0.6564 - val_accuracy: 0.6357
# Epoch 4/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6563 - val_accuracy: 0.6357
# Epoch 5/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6562 - val_accuracy: 0.6357
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 6/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6563 - val_accuracy: 0.6357
# Epoch 7/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6558 - accuracy: 0.6356 - val_loss: 0.6566 - val_accuracy: 0.6357
# Epoch 8/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6557 - accuracy: 0.6356 - val_loss: 0.6563 - val_accuracy: 0.6357
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 9/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6557 - accuracy: 0.6356 - val_loss: 0.6564 - val_accuracy: 0.6357
# Epoch 10/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6558 - accuracy: 0.6356 - val_loss: 0.6563 - val_accuracy: 0.6357
# Epoch 11/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6558 - accuracy: 0.6356 - val_loss: 0.6564 - val_accuracy: 0.6357
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 12/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6558 - accuracy: 0.6356 - val_loss: 0.6562 - val_accuracy: 0.6357
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# Epoch 1/250
# 1125/1125 [==============================] - 5s 4ms/step - loss: 0.9024 - accuracy: 0.6356 - val_loss: 0.6759 - val_accuracy: 0.6357
# Epoch 2/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6606 - accuracy: 0.6356 - val_loss: 0.6558 - val_accuracy: 0.6357
# Epoch 3/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6556 - val_accuracy: 0.6357
# Epoch 4/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6558 - accuracy: 0.6356 - val_loss: 0.6554 - val_accuracy: 0.6357
# Epoch 5/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6556 - accuracy: 0.6356 - val_loss: 0.6548 - val_accuracy: 0.6357
# Epoch 6/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6555 - accuracy: 0.6356 - val_loss: 0.6542 - val_accuracy: 0.6357
# Epoch 7/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6553 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6357
# Epoch 8/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6552 - accuracy: 0.6356 - val_loss: 0.6534 - val_accuracy: 0.6357
# Epoch 9/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6551 - accuracy: 0.6356 - val_loss: 0.6535 - val_accuracy: 0.6357
# Epoch 10/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6523 - val_accuracy: 0.6357
# Epoch 11/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6539 - accuracy: 0.6356 - val_loss: 0.6513 - val_accuracy: 0.6357
# Epoch 12/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6532 - accuracy: 0.6356 - val_loss: 0.6504 - val_accuracy: 0.6357
# Epoch 13/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6530 - accuracy: 0.6356 - val_loss: 0.6502 - val_accuracy: 0.6357
# Epoch 14/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6523 - accuracy: 0.6356 - val_loss: 0.6498 - val_accuracy: 0.6357
# Epoch 15/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6525 - accuracy: 0.6355 - val_loss: 0.6494 - val_accuracy: 0.6360
# Epoch 16/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6523 - accuracy: 0.6355 - val_loss: 0.6494 - val_accuracy: 0.6360
# Epoch 17/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6523 - accuracy: 0.6355 - val_loss: 0.6500 - val_accuracy: 0.6357
# Epoch 18/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6522 - accuracy: 0.6356 - val_loss: 0.6501 - val_accuracy: 0.6357
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 19/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6520 - accuracy: 0.6355 - val_loss: 0.6501 - val_accuracy: 0.6357
# Epoch 20/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6519 - accuracy: 0.6356 - val_loss: 0.6502 - val_accuracy: 0.6357
# Epoch 21/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6519 - accuracy: 0.6355 - val_loss: 0.6500 - val_accuracy: 0.6357
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 22/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6517 - accuracy: 0.6355 - val_loss: 0.6504 - val_accuracy: 0.6360
# Epoch 23/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6518 - accuracy: 0.6355 - val_loss: 0.6502 - val_accuracy: 0.6357
# Epoch 24/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6517 - accuracy: 0.6355 - val_loss: 0.6501 - val_accuracy: 0.6360
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 25/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6518 - accuracy: 0.6355 - val_loss: 0.6498 - val_accuracy: 0.6360
# Restoring model weights from the end of the best epoch.
# Epoch 00025: early stopping
# Epoch 1/250
# 1125/1125 [==============================] - 5s 4ms/step - loss: 1.2924 - accuracy: 0.6356 - val_loss: 0.6681 - val_accuracy: 0.6357
# Epoch 2/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6583 - accuracy: 0.6356 - val_loss: 0.6567 - val_accuracy: 0.6357
# Epoch 3/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6561 - accuracy: 0.6356 - val_loss: 0.6564 - val_accuracy: 0.6357
# Epoch 4/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6563 - val_accuracy: 0.6357
# Epoch 5/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6562 - val_accuracy: 0.6357
# Epoch 6/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6563 - val_accuracy: 0.6357
# Epoch 7/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6555 - accuracy: 0.6356 - val_loss: 0.6552 - val_accuracy: 0.6357
# Epoch 8/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6541 - accuracy: 0.6356 - val_loss: 0.6548 - val_accuracy: 0.6357
# Epoch 9/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6357
# Epoch 10/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6536 - accuracy: 0.6356 - val_loss: 0.6546 - val_accuracy: 0.6357
# Epoch 11/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6535 - accuracy: 0.6356 - val_loss: 0.6546 - val_accuracy: 0.6357
# Epoch 12/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6533 - accuracy: 0.6356 - val_loss: 0.6547 - val_accuracy: 0.6357
# Epoch 13/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6534 - accuracy: 0.6356 - val_loss: 0.6544 - val_accuracy: 0.6357
# Epoch 14/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6528 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6357
# Epoch 15/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6533 - accuracy: 0.6356 - val_loss: 0.6547 - val_accuracy: 0.6357
# Epoch 16/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6533 - accuracy: 0.6356 - val_loss: 0.6546 - val_accuracy: 0.6357
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 17/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6529 - accuracy: 0.6356 - val_loss: 0.6546 - val_accuracy: 0.6357
# Epoch 18/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6528 - accuracy: 0.6356 - val_loss: 0.6545 - val_accuracy: 0.6357
# Epoch 19/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6530 - accuracy: 0.6356 - val_loss: 0.6547 - val_accuracy: 0.6357
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 20/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6529 - accuracy: 0.6356 - val_loss: 0.6546 - val_accuracy: 0.6357
# Epoch 21/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6530 - accuracy: 0.6356 - val_loss: 0.6546 - val_accuracy: 0.6357
# Epoch 22/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6528 - accuracy: 0.6356 - val_loss: 0.6547 - val_accuracy: 0.6357
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 23/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6527 - accuracy: 0.6356 - val_loss: 0.6548 - val_accuracy: 0.6357
# Restoring model weights from the end of the best epoch.
# Epoch 00023: early stopping
# Epoch 1/250
# 1125/1125 [==============================] - 6s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 2/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 3/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 4/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 6/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 7/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 8/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 9/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 10/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 11/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Epoch 1/250
# 1125/1125 [==============================] - 5s 3ms/step - loss: 0.8206 - accuracy: 0.6356 - val_loss: 0.6581 - val_accuracy: 0.6355
# Epoch 2/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6561 - accuracy: 0.6356 - val_loss: 0.6549 - val_accuracy: 0.6355
# Epoch 3/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6542 - accuracy: 0.6356 - val_loss: 0.6537 - val_accuracy: 0.6355
# Epoch 4/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6531 - accuracy: 0.6356 - val_loss: 0.6537 - val_accuracy: 0.6355
# Epoch 5/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6526 - accuracy: 0.6356 - val_loss: 0.6536 - val_accuracy: 0.6355
# Epoch 6/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6523 - accuracy: 0.6355 - val_loss: 0.6535 - val_accuracy: 0.6355
# Epoch 7/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6519 - accuracy: 0.6356 - val_loss: 0.6534 - val_accuracy: 0.6348
# Epoch 8/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6518 - accuracy: 0.6354 - val_loss: 0.6531 - val_accuracy: 0.6355
# Epoch 9/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6517 - accuracy: 0.6356 - val_loss: 0.6532 - val_accuracy: 0.6355
# Epoch 10/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6356 - val_loss: 0.6532 - val_accuracy: 0.6355
# Epoch 11/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6512 - accuracy: 0.6357 - val_loss: 0.6530 - val_accuracy: 0.6355
# Epoch 12/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6511 - accuracy: 0.6357 - val_loss: 0.6530 - val_accuracy: 0.6355
# Epoch 13/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6509 - accuracy: 0.6356 - val_loss: 0.6532 - val_accuracy: 0.6355
# Epoch 14/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6508 - accuracy: 0.6356 - val_loss: 0.6527 - val_accuracy: 0.6357
# Epoch 15/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6507 - accuracy: 0.6356 - val_loss: 0.6527 - val_accuracy: 0.6357
# Epoch 16/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6504 - accuracy: 0.6353 - val_loss: 0.6533 - val_accuracy: 0.6363
# Epoch 17/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6505 - accuracy: 0.6357 - val_loss: 0.6529 - val_accuracy: 0.6360
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 18/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6499 - accuracy: 0.6359 - val_loss: 0.6527 - val_accuracy: 0.6360
# Epoch 19/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6496 - accuracy: 0.6356 - val_loss: 0.6527 - val_accuracy: 0.6357
# Epoch 20/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6496 - accuracy: 0.6356 - val_loss: 0.6526 - val_accuracy: 0.6357
# Epoch 21/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6499 - accuracy: 0.6354 - val_loss: 0.6526 - val_accuracy: 0.6360
# Epoch 22/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6497 - accuracy: 0.6360 - val_loss: 0.6527 - val_accuracy: 0.6357
# Epoch 23/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6500 - accuracy: 0.6357 - val_loss: 0.6526 - val_accuracy: 0.6357
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 24/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6496 - accuracy: 0.6359 - val_loss: 0.6528 - val_accuracy: 0.6357
# Epoch 25/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6497 - accuracy: 0.6356 - val_loss: 0.6526 - val_accuracy: 0.6357
# Epoch 26/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6495 - accuracy: 0.6358 - val_loss: 0.6527 - val_accuracy: 0.6357
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 27/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6498 - accuracy: 0.6357 - val_loss: 0.6526 - val_accuracy: 0.6357
# Epoch 28/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6497 - accuracy: 0.6356 - val_loss: 0.6527 - val_accuracy: 0.6355
# Epoch 29/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6495 - accuracy: 0.6356 - val_loss: 0.6526 - val_accuracy: 0.6357
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 30/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6495 - accuracy: 0.6357 - val_loss: 0.6526 - val_accuracy: 0.6357
# Restoring model weights from the end of the best epoch.
# Epoch 00030: early stopping
# Epoch 1/250
# 1125/1125 [==============================] - 5s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 2/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 3/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 4/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 6/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 7/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 8/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 9/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 10/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 11/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Epoch 1/250
# 1125/1125 [==============================] - 5s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 2/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 3/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 4/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 6/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 7/250
# 1125/1125 [==============================] - 3s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 8/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 9/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Epoch 10/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 11/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 5.6207 - accuracy: 0.6356 - val_loss: 5.6224 - val_accuracy: 0.6355
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Epoch 1/250
# 1125/1125 [==============================] - 5s 4ms/step - loss: 0.9128 - accuracy: 0.6356 - val_loss: 0.6588 - val_accuracy: 0.6355
# Epoch 2/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6567 - accuracy: 0.6356 - val_loss: 0.6562 - val_accuracy: 0.6355
# Epoch 3/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6560 - accuracy: 0.6356 - val_loss: 0.6565 - val_accuracy: 0.6355
# Epoch 4/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6560 - val_accuracy: 0.6355
# Epoch 5/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6555 - accuracy: 0.6356 - val_loss: 0.6559 - val_accuracy: 0.6355
# Epoch 6/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6550 - accuracy: 0.6356 - val_loss: 0.6560 - val_accuracy: 0.6355
# Epoch 7/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6546 - accuracy: 0.6356 - val_loss: 0.6568 - val_accuracy: 0.6355
# Epoch 8/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6548 - accuracy: 0.6356 - val_loss: 0.6563 - val_accuracy: 0.6355
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 9/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6544 - accuracy: 0.6356 - val_loss: 0.6563 - val_accuracy: 0.6355
# Epoch 10/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6563 - val_accuracy: 0.6355
# Epoch 11/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6563 - val_accuracy: 0.6355
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 12/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6564 - val_accuracy: 0.6355
# Epoch 13/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6564 - val_accuracy: 0.6355
# Epoch 14/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6544 - accuracy: 0.6356 - val_loss: 0.6564 - val_accuracy: 0.6355
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 15/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6545 - accuracy: 0.6356 - val_loss: 0.6564 - val_accuracy: 0.6355
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# Epoch 1/250
# 1125/1125 [==============================] - 6s 4ms/step - loss: 0.7492 - accuracy: 0.6356 - val_loss: 0.6557 - val_accuracy: 0.6355
# Epoch 2/250
# 1125/1125 [==============================] - 5s 5ms/step - loss: 0.6559 - accuracy: 0.6356 - val_loss: 0.6552 - val_accuracy: 0.6355
# Epoch 3/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6554 - accuracy: 0.6356 - val_loss: 0.6546 - val_accuracy: 0.6355
# Epoch 4/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6542 - accuracy: 0.6356 - val_loss: 0.6539 - val_accuracy: 0.6355
# Epoch 5/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6533 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6355
# Epoch 6/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6526 - accuracy: 0.6356 - val_loss: 0.6537 - val_accuracy: 0.6355
# Epoch 7/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6525 - accuracy: 0.6356 - val_loss: 0.6538 - val_accuracy: 0.6355
# Epoch 8/250
# 1125/1125 [==============================] - 5s 4ms/step - loss: 0.6522 - accuracy: 0.6355 - val_loss: 0.6537 - val_accuracy: 0.6357
# Epoch 9/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6522 - accuracy: 0.6355 - val_loss: 0.6535 - val_accuracy: 0.6357
# Epoch 10/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6521 - accuracy: 0.6356 - val_loss: 0.6536 - val_accuracy: 0.6352
# Epoch 11/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6520 - accuracy: 0.6355 - val_loss: 0.6539 - val_accuracy: 0.6352
# Epoch 12/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6516 - accuracy: 0.6355 - val_loss: 0.6537 - val_accuracy: 0.6350
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6516 - accuracy: 0.6354 - val_loss: 0.6537 - val_accuracy: 0.6350
# Epoch 14/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6517 - accuracy: 0.6356 - val_loss: 0.6537 - val_accuracy: 0.6350
# Epoch 15/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6514 - accuracy: 0.6355 - val_loss: 0.6537 - val_accuracy: 0.6350
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 16/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6516 - accuracy: 0.6355 - val_loss: 0.6536 - val_accuracy: 0.6350
# Epoch 17/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6510 - accuracy: 0.6355 - val_loss: 0.6537 - val_accuracy: 0.6350
# Epoch 18/250
# 1125/1125 [==============================] - 4s 4ms/step - loss: 0.6515 - accuracy: 0.6355 - val_loss: 0.6537 - val_accuracy: 0.6350
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 19/250
# 1125/1125 [==============================] - 4s 3ms/step - loss: 0.6515 - accuracy: 0.6355 - val_loss: 0.6537 - val_accuracy: 0.6350
# Restoring model weights from the end of the best epoch.
# Epoch 00019: early stopping

# %% [markdown]
# # Submissions

# %%
submissions = pd.read_csv('../input/song-popularity-prediction/sample_submission.csv')
submissions['song_popularity'] = np.array(preds).mean(axis=0)
submissions.to_csv('preds.csv', index=False)
